# %%
import pandas  as pd
import numpy as np
import requests
import pickle as pkl

# %%
with open('pickles\\df2_uncleaned2.pkl', 'rb') as fl:
    df = pkl.load(fl)
df
# Out:
#                    date                                              title  \
# 0         June 04, 2020                    Talk to the People. on COVID-19
# 1        April 23, 2020                     Talk to the Nation on COVID-19
# 2        March 24, 2020                                        On COVID-19
# 3        March 09, 2020          Opening statement at briefing on COVID-19
# 4        April 17, 2019                       PDP-Laban campaign, Batangas
# ..                  ...                                                ...
# 300     October 4, 2016                             Sulong Pilipinas-Luzon
# 301     October 4, 2016                    Philippine Army, Fort Bonifacio
# 302    October 02, 2016               37th Masskara Festival, Bacolod City
# 303  September 30, 2016  9th National Biennial Summit on Women in Conmm...
# 304  September 30, 2016                                 Arrival from Hanoi
#
#                                                    url  \
# 0    https://www.mindanews.com/duterte-files/2020/0...
# 1    https://www.mindanews.com/duterte-files/2020/0...
# 2    https://www.mindanews.com/mindaviews/2020/03/d...
# 3    https://www.mindanews.com/duterte-files/2020/0...
# 4    https://www.mindanews.com/duterte-files/2019/0...
# ..                                                 ...
# 300  https://www.mindanews.com/duterte-files/2016/1...
# 301  https://www.mindanews.com/duterte-files/2016/1...
# 302  https://www.mindanews.com/duterte-files/2016/1...
# 303  https://www.mindanews.com/duterte-files/2016/1...
# 304  https://www.mindanews.com/duterte-files/2016/1...
#
#                                             transcript  \
# 0    \nPRESIDENT RODRIGO ROA DUTERTE: Let us start ...
# 1    \nPRESIDENT DUTERTE: Maraming salamat Presiden...
# 2    It has been a week since we called for a Commu...
# 3    As usual I am late because my boat will not st...
# 4    Kindly sit down. Magandang gabi po sa inyong l...
# ..                                                 ...
# 300  SPEECH OF\n PRESIDENT RODRIGO ROA DUTERTE\n DU...
# 301  Presidential Communications Office\nPresidenti...
# 302  Presidential Communications Office \nPresident...
# 303  PRESIDENTIAL COMMUNICATIONS OFFICE \nPRESIDENT...
# 304  \nPRESIDENT DUTERTE: Good morning ma’am.\nPRES...
#
#                                              locations
# 0                                           Davao City
# 1                                                  NaN
# 2                                        23 March 2020
# 3            the Heroes Hall, Malacañan Palace, Manila
# 4    Batangas City Sports Center – Coliseum, Batang...
# ..                                                 ...
# 300  Mayuree Grand Ballroom, Dusit Thani Hotel, Mak...
# 301                        Fort Bonifacio, Taguig City
# 302  Bacolod City Public Plaza, Bacolod City, Negro...
# 303                         Apo View Hotel, Davao City
# 304                                         Davao City
#
# [305 rows x 5 columns]

# %%
import re
def is_in(txt):
    if any(((txt.lower() in trans) or (trans in txt.lower())) for trans in df.transcript.values.tolist()):
        return True
    else:
        return False

def clean_transcript(single_str):
    lt_names= ['PRESIDENT RODRIGO DUTERTE:', 'PRESIDENT DUTERTE:', 'PRESIDENT RODRIGO ROA DUTERTE:', 'DUTERTE:', 
               'PRES. DUTERTE:', 'PRRD']
    str_cleaned = single_str
    for nm in lt_names:
        str_cleaned = str_cleaned.replace(nm, ' ')
    str_cleaned = str_cleaned.replace('\xa0', ' ')
    str_cleaned = str_cleaned.replace('\x0c', ' ')
    str_cleaned = str_cleaned.replace('\\', ' ')
    str_cleaned = str_cleaned.replace('—', ' ')
    str_cleaned = str_cleaned.replace('-', ' ')
    str_cleaned = str_cleaned.replace('...', ' ')
    str_cleaned = str_cleaned.replace('…', ' ')
    str_cleaned = str_cleaned.replace('END', ' ')
    str_cleaned = re.sub(r"\[(.*?)\]", ' ', str_cleaned) #remove all that is contained within brackets
    str_cleaned = re.sub(r"\((.*?)\)", ' ', str_cleaned) #remove all that is contained within parentheses
    str_cleaned = re.sub(r'\“(.+?)\”', ' ', str_cleaned) #remove all that is in quatation as he probably quoting someone
    str_cleaned = str_cleaned.replace('‘', ' ')
    str_cleaned = [wrd.lower() for wrd in str_cleaned.split(' ') if wrd != '']
    str_cleaned = ' '.join(str_cleaned)

    return str_cleaned

def find_occur(target, key,  num=-1, offset=10):
    if num == -1:
        num = count_num_occur(target, key)
    #check if word is a list or a string
    if type(key) == str:
        key = [key]
    target_lt = target.split(" ")
    lt = []
    count_num_target = 0
    count_num_words = 0
    isSame = False
    
    for i in range(len(target_lt)):
        if target_lt[i] == key[0]:
            isSame= True
            #check if the remaining words are also equal
            for j in range(len(key)):
                if target_lt[j + i] != key[j]:
                    isSame = False
                    break
                    
            if isSame:
                count_num_target += 1
                txt = ''
            if count_num_target == num:
                break
        
        if isSame:
            txt += ' ' + target_lt[i]
            count_num_words += 1
            #once we reached the offset
            if count_num_words == offset:
                isSame = False
                lt.append(txt)
                count_num_words = 0
                txt = ''
        
    return lt

# %%
full_txt = ' '.join(df.transcript.tolist())

# %%
cleaned_txt = clean_transcript(full_txt)

# %%
find_occur(cleaned_txt, 'b****', num=20)
# Out:
# [' b**** nila dun sa ano, marunong mag ingles eh. so',
#  ' b**** na mag sige mag yawyaw diyan now is not',
#  ' b**** talaga kaya hanggang human rights lang kayo.tapos takot takotin',
#  ' b**** niya defines',
#  ' b**** niya, yung sa likod, yung pinakamalaki, it is really',
#  ' b**** nila dun sa ano, marunong mag ingles eh. so',
#  ' b**** or that is not the problem of not even',
#  ' b**** who once administered the affairs of the country for',
#  ' b**** mo. congenital. kayabang mo. maglaban kaya sa akin ng',
#  ' b**** s***.kaya tama yung si pulong. dapat ninyo makita ang',
#  ' b**** diyan sa korte. so sabi ko, kasi hindi tayo',
#  ' b**** man yung mga ganon na tao.doon mo ilagay yan',
#  ' b**** man yung rekomendasyon na yun.\n you know, the president',
#  ' b**** yung nagdesisyon. there are maybe siguro another damages but',
#  ' b**** running a rampage there.eh, malas lang talaga. i’m sorry',
#  ' b**** mo diyan. o sige sampalin mo pa uli.’ mayor,',
#  ' b**** yung mga namatay? iyon numero nila yon pero hindi',
#  ' b**** talaga sa atin is p***** i***, ganun, iniba, son']

# %%
find_occur(cleaned_txt, 'f***', num=20, offset=100)
# Out:
# [' f*** with drugs because if you destroy my country while i am there sitting, p***** i** mo papatayin talaga kita. hindi ako napagtapang tapangan. wala akong ibig sabihin. may trabaho lang ako. kung gusto mo, eh pagkatapos ko ng presidente. eh di kung may galit ka, may personal na galit kayo, sige. gisingin mo lang ako, pagbigyan kita maski tulog ako. ganun yan eh.ngayon, from yung warning, yung warning ni secretary ni alunan noon during the time of marcos in pagkatapos i’m sorry not marcos aquino, corazon.from then on, kay marcos siya. ah kay ramos rather siya. naging secretary. but',
#  ' f*** with government. hirap na nga ang tao. at saka yung drive ko against corruption, bantay kayo diyan.even a whiff, maamoy ko lang. hindi ko na kailangan i would not go into the length of finding out. even a whiff of corruption, you go.ayaw mo, mag suplado ka, eh nasa sa iyo yan. you want a legal method of doing it? resign or not.eh galing ako ng lugar ng mindanao. puro wala kaming ano na solution eh, patayan eh. yan ang dala dala ko dito sa presidency ko. wala man akong alam na ibang solution. i’ll be firing two. it?]you',
#  ' f*** with us. we asean members can export to each other. we can also have tariff free.and you have the problem there of terrorism. you imported it in your country. you built your riches. you were ahead in the industrial race of the planet earth because you stole the greatest resource of the arabs and that was that’s oil.kaya nauna kayo and you paid a pittance for the raw materials. from where? from the middle east. you colonize, lahat. then started to divide middle east, united states, uk, france, kayo yun eh. and that is why you are paying heavily']

# %%
find_occur(cleaned_txt, 'g***', num=20)
# Out:
# [' g*** magsabi try to to ramble on to some other',
#  ' g*** to. kung magsalita akala mo sabi nila, p**** i**.',
#  ' g*** lang ang tao hindi maniwala ng diyos.kaya lang sabihin',
#  ' g*** eh. mag import, pagdating doon, seizure kasi walang consignee,',
#  ' g*** na yan, pati siya nagkakaroon ng bisita sa loob',
#  ' g*** na hangin dito. ano, sir? ikaw na ang mag',
#  ' g*** yan, sinabi ko wala nang bukas bukas ng mga',
#  ' g*** sa barangay niya. eh alam niya regularly may pera',
#  ' g*** tahimik. ngayon kami pa ang masama. sabihin ganun, ganun,',
#  ' g*** naman. pag ka eh patayin mo lahat yung kristiyanos,',
#  ' g*** magkabarkada tayo huwag mong maglagay diyan, kabarkada mo yan.',
#  ' g*** na hindi naman iniintindi, nagpapakamatay kayo ng isang tao,',
#  ' g*** to. kung magsalita akala mo sabi nila, p**** i**.',
#  ' g*** lang ang tao hindi maniwala ng diyos.kaya lang sabihin',
#  ' g*** talaga yan. pamilya ni inday pati pamilya nung isa',
#  ' g*** ka pala. alam mo na hindi pwede yan. kaya',
#  ' g*** kasi tong mga sabi kasi nila sinabi ko what',
#  ' g*** na, natulilit na. and why? because shabu makes my',
#  ' g*** na yan.they kill for nothing, they destroy for nothing.']

# %%
find_occur(cleaned_txt, ['p*****', 'i**'], num=20)
# Out:
# [' p***** i** dalawang buwan itong lecheng ito.can you just imagine,',
#  ' p***** i** kayo, sinabi ko na sa inyo eh talagang',
#  ' p***** i** ka, makinig kayo sa akin.ang pilipinas hindi talaga',
#  ' p***** i** pa rebelde rebelde ka pa diyan. hindi ka',
#  ' p***** i**',
#  ' p***** i** huwag ninyong gawain yan. papatayin ko sabi ko',
#  ' p***** i** mo papatayin talaga kita. hindi ako napagtapang tapangan.',
#  ' p***** i** ninyo do not destroy my country. do not',
#  ' p***** i** pakainin mo ng shabu.what about me? ako? akong',
#  ' p***** i** sa bayan to, nandoon lahat, mga mayors. kaya',
#  ' p***** i** ka.ilang pulis na ang namatay ko? ang pulis',
#  ' p***** i** sa general, kung ikaw ang nandoon anong gawin',
#  ' p***** i** kayo. sabi ko sa inyo ipalabas ko yan',
#  ' p***** i** hindi ko lang pinapansin. nung malapit na sa',
#  ' p***** i** ko, sabi ko, tapos yung last sabi niya',
#  ' p***** i** ka, ikaw yung may sakit na diabetes, 30',
#  ' p***** i** ganun. you you earn your millions. ang kapital',
#  ' p***** i** dalawa, maraming pera, isang bulto. sabi nung isa,']
