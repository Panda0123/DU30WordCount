# %% [markdown]
# # PRESIDENT DUTERTE'S WORD COUNT
# by: Jamsed Cabili

# %% [markdown]
# # TABLE OF CONTENTS
#
# 1. [Number of Transcripts Scraped](#section1)
#
#     1.1 [Total Number of Transcrips](#section11)
#
#     1.2 [Number of Transcripts Yearly basis](#section12)
#
#     1.3 [Number of Transcripts Monthly basis](#section13)
#
#     1.4 [Total Number of Words](#section14)
#
#
# 2. [Word Cloud](#section2)
#
#     2.1 [Word Cloud of All Transcripts](#section21)
#
#     2.2 [Word Cloud of 2016 Transcripts](#section22)
#
#     2.3 [Word Cloud of 2017 Transcripts](#section23)
#
#     2.4 [Word Cloud of 2018 Transcripts](#section24)
#
#     2.5 [Word Cloud of 2019 Transcripts](#section25)
#
#     2.6 [Word Cloud of 2020 Transcripts](#section26)
#
#
# 3. [Word Count of Specific Words](#section3)
#
#     3.1 [Health, Education, Safety, Love, Kill, Putangina](#section31)
#
#     3.2 [Kalusugan,  Edukasyon, Kaligtasan, Mahal, Patayin, Putangina](#section32)
#
#     3.3 [Combine](#section33)
#
#
#
# 4. [Countries Frequently Mentioned](#section4)
#
#
# 5. [Nationality Frequently Mentioned](#section5)
#
#
# 6. [Frequency Mentioned his top donors' Last Name](#section6)
#
#
# 7. [Favorite Swear Words](#section7)
#
#
# 8. [Number of times Mentioned 'Bong'](#section8)
#
#     8.1 [Mentioned 'Bong' Yearly basis](#section81)
#
#     8.2 [Mentioned 'Bong' Monthly basis](#section82)

# %%
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib .pyplot as plt
import seaborn as sns

# %% [markdown]
# >Let's load the file

# %%
with open('pickles\\df.pkl', 'rb') as fl:
    df = pkl.load(fl)
df
# Out:
#           date                                              title  \
# 0   2020-05-26  Excerpts from Speech of President Rodrigo Roa ...
# 1   2020-05-25  Talk to the People of President Rodrigo Roa Du...
# 2   2020-05-22  Speech of President Rodrigo Roa Duterte during...
# 3   2020-05-19  Talk to the People of President Rodrigo Roa Du...
# 4   2020-05-12  Talk to the People of President Rodrigo Roa Du...
# ..         ...                                                ...
# 786 2016-12-14                            Royal Banquet, Cambodia
# 787 2016-11-29                    Inauguration of Mega Drug Rehab
# 788 2016-10-27                                 Arrival from Japan
# 789 2016-10-21                     Arrival from China and Q and A
# 790 2016-10-13                     Philippine Business Conference
#
#                                                    url  \
# 0    https://pcoo.gov.ph/presidential-speech/excerp...
# 1    https://pcoo.gov.ph/presidential-speech/talk-t...
# 2    https://pcoo.gov.ph/presidential-speech/speech...
# 3    https://pcoo.gov.ph/presidential-speech/talk-t...
# 4    https://pcoo.gov.ph/presidential-speech/talk-t...
# ..                                                 ...
# 786  https://www.mindanews.com/duterte-files/2016/1...
# 787  https://www.mindanews.com/duterte-files/2016/1...
# 788  https://www.mindanews.com/duterte-files/2016/1...
# 789  https://www.mindanews.com/duterte-files/2016/1...
# 790  https://www.mindanews.com/duterte-files/2016/1...
#
#                                                  event  \
# 0    Meeting with Philippine Army (PA) and Philippi...
# 1               On Coronavirus Disease 2019 (COVID-19)
# 2    Commencement Exercsies of the Philippine Milit...
# 3               On Coronavirus Disease 2019 (COVID-19)
# 4               On Coronavirus Disease 2019 (COVID-19)
# ..                                                 ...
# 786                                                NaN
# 787                                                NaN
# 788                                                NaN
# 789                                                NaN
# 790                                                NaN
#
#                                               location  \
# 0           Malago Clubhouse, Malacañang Park, Manila
# 1                       Malago Clubhouse in Malacañang
# 2           Malago Clubhouse, Malacañang Park, Manila
# 3                       Malago Clubhouse in Malacañang
# 4                       Malago Clubhouse in Malacañang
# ..                                                 ...
# 786  Reception Hall, Preah Reach Damnak Serei Mongk...
# 787          Fort Magsaysay, Palayan City, Nueva Ecija
# 788                        Davao International Airport
# 789            Davao International Airport, Davao City
# 790                         Marriott Hotel, Pasay City
#
#                                             transcript
# 0    so ako pati si bong during my mayorship days s...
# 1    i remember distinctly very well that noong nap...
# 2    kindly sit down. , defense secretary delfin lo...
# 3    good evening my countrymen. today is may 19, t...
# 4    sir, one question. itong opening, limited move...
# ..                                                 ...
# 786  your majesty, preah bat samdech preah boromnea...
# 787  kindly sit down. maraming salamat po.secretary...
# 788  i am glad to be back from my official trip to ...
# 789  do you mind that i dispense with the acknowled...
# 790  kindly sit down. salamat po.secretary carlos d...
#
# [791 rows x 6 columns]

# %% [markdown]
# >I'm gonna create functions that we will be calling repeatedly in this section.

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
with open('Filipino_Stopwords.txt', 'r') as fl:
    fil_stop_words = fl.read().split('\n')

all_stop_words = fil_stop_words
all_stop_words.extend(ENGLISH_STOP_WORDS)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer

def remove_stop(txt=_, stop_words=all_stop_words):
    '''remove stop words from a string'''
    full_txt = ''
    list_to_remove = [':', ',', '.', '’', '‘', '\'', '„', '?', '!', '‟', '`', '"', '‗']
    for rem in list_to_remove:
        txt = txt.replace(rem, '')
    
    for wrd in txt.replace('\n', ' ').split(' '):
        if not wrd in stop_words:
            full_txt += ' ' + wrd
#             if 'yung' in wrd:
#                 print(wrd)
    return full_txt

def remove_stop_lt(txt_lt=_, stop_words=all_stop_words):
    '''remove stop words from a list of string'''
    list_to_remove = [':', ',', '.', '’', '‘', '\'', '„', '?', '!', '‟', '`', '"', '‗']
    for i in range(len(txt_lt)):
        txt = txt_lt[i]
        full_txt = ''
        for rem in list_to_remove:
            txt = txt.replace(rem, '')

        for wrd in txt.replace('\n', ' ').split(' '):
            if not wrd in stop_words:
                full_txt += ' ' + wrd

        txt_lt[i] == full_txt
    return txt_lt


def concat_ser(ser):
    '''concatenate the series and return one string'''
    return ' '.join(ser.tolist())
    
    
def create_word_cloud(data, ax=plt):
    '''creates a word cloud from a series or a string'''
    if type(data) == pd.Series:
        data = concat_ser(data)
    all_stop_words = fil_stop_words
    all_stop_words.extend(ENGLISH_STOP_WORDS)

    wc = WordCloud(background_color='white', mode='RGB')
    data = remove_stop( data, all_stop_words)
    wc.generate(data)
    ax.imshow(wc, interpolation='bilinear')
    ax.axis('off')

def create_word_cloud2(dict_freq, stop_words=all_stop_words, ax=plt):
    """
    Create a word cloud from dictionary frequency
    """
    wc = WordCloud(stopwords=stop_words, background_color='white', colormap='Dark2', random_state=42)
    wc.generate_from_frequencies(dict_freq)
    ax.imshow(wc, interpolation='bilinear')
    ax.axis('off')

def create_word_cloud_tfidf(data, ax=plt):
    all_stop_words = fil_stop_words
    all_stop_words.extend(ENGLISH_STOP_WORDS)

    data = remove_stop_lt(data, all_stop_words)
    vectorizer = TfidfVectorizer(norm=None)

    vectorizer.fit(data)

    transformed = vectorizer.transform(data)
    max_val = transformed.max(axis=0).toarray().ravel()
    max_val_sorted_index = max_val.argsort()
    feature_names = np.array(vectorizer.get_feature_names())
    dict_frequency = {}

    for i in range(len(max_val)):
        word = feature_names[max_val_sorted_index[i]]
        weight = max_val[max_val_sorted_index[i]]
        dict_frequency[word] = weight
    create_word_cloud2(dict_frequency, ax=ax)

def count_num_occur(target, key):
    """
    Count the number of occurences of a key in target (if a key is equal to a word)
    """
    count = 0
    if type(key) == str:
        key = [key]
        
    lt_target = target.split(' ')
    for i in range(len(lt_target)):
        wrd = lt_target[i]
        if wrd == key[0]:
            isSame = True
            for j in range(len(key)):
                #check if it exceeded the length of the target and if not equal
                if  len(lt_target) != i + j and key[j] != lt_target[j + i]:
                    isSame =False
                    break
               
            if isSame:
                count += 1
    return count

def count_num_occur_in(target, key):
    """
    Count the number of occurences of a key in target (if a key exist in a word)
    """
    count = 0
    if type(key) == str:
        key = [key]
        
    lt_target = target.split(' ')
    for i in range(len(lt_target)):
        wrd = lt_target[i]
        if wrd in key[0]:
            isSame = True
            for j in range(len(key)):
                #check if it exceeded the length of the target and if not equal
                if  len(lt_target) != i + j and key[j] not in lt_target[j + i]:
                    isSame =False
                    break
               
            if isSame:
                count += 1
    return count

def count_num_occur_multi_keys(target, keys):
    """
    Count the number of occurences of multiple keys in a target (if the keys are euqal to a word)
    """
    names = keys
    count = 0

    #first find if contain multiple names
    if keys.find('|') != -1:
        names = [x.strip() for x in keys.split('|')]
        for name in names:
            count += count_num_occur(target, name.split(' '))
    else:
        count = count_num_occur(target, keys.split(' '))
        
    return count

from matplotlib import transforms
def rainbow_text(x, y, strings, colors, size, orientation='horizontal',
                 ax=None,  **kwargs):
    """
    So a line of text can have multiple colors in our graph
    """
    if ax is None:
        ax = plt.gca()
    t = ax.transData
    canvas = ax.figure.canvas

    assert orientation in ['horizontal', 'vertical']
    if orientation == 'vertical':
        kwargs.update(rotation=90, verticalalignment='bottom')

    for s, c, si in zip(strings, colors, size):
        text = ax.text(x, y, s, color=c, transform=t, fontdict={'fontsize':si}, **kwargs)

        # Need to draw to update the text position.
        text.draw(canvas.get_renderer())
        ex = text.get_window_extent()
        if orientation == 'horizontal':
            t = transforms.offset_copy(
                text.get_transform(), x=ex.width, units='dots')
        else:
            t = transforms.offset_copy(
                text.get_transform(), y=ex.height, units='dots')
            
def show_number(counts, words=None, x_offset=0, y_offset=0, orientation='vertical', 
                round_off=False, dec_place=0, ax=plt, colors=None, **kwargs):
    """Shows number in the bag graph"""
    if not words:
        words = counts 
        
    if round_off:
        if dec_place == 0:
            counts = np.round(counts, 0).astype(int)
        else:
            counts = np.round(counts, dec_place)
    if orientation == 'vertical':
        if colors:
            if 'fontdict' in kwargs:
                font_val = kwargs['fontdict']
                del kwargs['fontdict']

            for i, (word, count, col) in enumerate(zip(words, counts, colors)):
                font_val['color'] = col
                ax.text(i+x_offset, count+y_offset, word, fontdict=font_val, **kwargs )
                del font_val['color']
        else:
            for i, (word, count) in enumerate(zip(words, counts)):
                ax.text(i+x_offset, count+y_offset, word, **kwargs)
    else:
        if colors:
            if 'fontdict' in kwargs:
                font_val = kwargs['fontdict']
                del kwargs['fontdict']

            for i, (word, count, col) in enumerate(zip(words, counts, colors)):
                font_val['color'] = col
                ax.text(count+x_offset, i+y_offset, word, fontdict=font_val, **kwargs )
                del font_val['color']
        else:
            for i, (word, count) in enumerate(zip(words, counts)):
                ax.text(count+x_offset, i+y_offset, word, **kwargs)
        

def get_size_color(colors, size_black, size_others):
    sizes = []
    col = []
    for color in colors:
        if color == 'black':
            sizes.append(size_black)
            col.append(color)
        elif color == 'black2':#for quotation same size with others but different color
            sizes.append(size_others)
            col.append('black')
        else:
            sizes.append(size_others)
            col.append(color)
            
    return sizes, col

# %% [markdown]
# # 1. Number of Transcripts <div id='section1'> </div>

# %% [markdown]
# ## 1.1Total number of Transcripts <div id='section11'> </div>

# %%
full_txt = concat_ser(df.transcript)
full_txt = remove_stop(full_txt)
df_all = pd.Series(data={'num_transcript': df.transcript.shape[0], 'concat_trans':full_txt}, name='all').to_frame().T
print(f'Total Number of Transcripts: {df_all.num_transcript.values[0]}')
display(df_all)
# Out:
# Total Number of Transcripts: 791
#     num_transcript                                       concat_trans
# all            791   pati bong mayorship days moment bong right na...

# %% [markdown]
# ## 1.2 Number of Transcripts Yearly Basis <div id='section12'> </div>

# %%
#group records by year
grouped_year = df.groupby(df.date.map(lambda x: x.year))

years = [2016, 2017, 2018, 2019, 2020]
concat_trans_years = []
size = []
for year in years:
    trans_ser = grouped_year.get_group(year).transcript
    size.append(trans_ser.shape[0])
    trans_str = concat_ser(trans_ser)
    trans_str = remove_stop(trans_str)
    concat_trans_years.append(trans_str)
df_years = pd.DataFrame(index=years, data={'concat_trans':concat_trans_years, 'num_trans':size})
display(df_years)
# Out:
#                                            concat_trans  num_trans
# 2016   president fidel ramos sir salamat tulong maki...        180
# 2017   kindly sit salamat secretary delfin lorenzana...        234
# 2018   salamat kindly sit agrarian reform secretary ...        195
# 2019   kindly sit sorry looking social welfare devel...        131
# 2020   pati bong mayorship days moment bong right na...         51

# %% [markdown]
# Let's plot it.

# %%
plt.figure(figsize=(5, 6))
df_years.num_trans.plot.bar(alpha=0.5)
plt.title('Number of Transcripts collected yearly basis', fontdict={'fontsize':14})
show_number(counts=df_years.num_trans.tolist(), x_offset=-0.1, y_offset=2)
sns.despine()
# plt.savefig('pictures\\Number_Transcripts_Years.png')

# %% [markdown]
# ## 1.3 Number of Transcripts collected by months <div id='section13'> </div>

# %%
#grouped by months
grouped_month = df.groupby(df.date.map(lambda x: (x.year, x.month)))

concat_trans_month = []
size = []
for group in grouped_month.groups:
    trans_ser = grouped_month.get_group(group).transcript
    size.append(trans_ser.shape[0])
    trans_str = concat_ser(trans_ser)
    trans_str = remove_stop(trans_str)
    concat_trans_month.append(trans_str)
    
#name months accordingly 
month = ['Jan.', 'Feb.', 'Mar.', 'Apr.', 'May', 'Jun.', 'Jul.', 'Aug.', 'Sep.', 'Oct.', 'Nov.', 'Dec.']
group_name = []
num_month_year = {}
for group in grouped_month.groups.keys():
    group_name.append(f'{group[0]}, {month[group[1]-1]}')
    #we're going to track the number of months in a year we have
    if group[0] in num_month_year.keys():
        num_month_year[group[0]] += 1
    else:
        num_month_year[group[0]] = 1

df_years['num_months'] = num_month_year.values()
df_months = pd.DataFrame(data={'date_str':group_name, 'concat_trans':concat_trans_month, 'num_trans':size}, 
                         index=grouped_month.groups)
display(df_months)
# Out:
#            date_str                                       concat_trans  \
# 2016 6   2016, Jun.   president fidel ramos sir salamat tulong maki...
#      7   2016, Jul.   let begin addressing officer brigadier genera...
#      8   2016, Aug.   intend interrupt ganito discourteous walk lot...
#      9   2016, Sep.   maayong hapon  let begin work id like remind ...
#      10  2016, Oct.   salamat kindly sit secretary judy taguiwalo; ...
#      11  2016, Nov.   wanted structures government destroyed occupi...
#      12  2016, Dec.   busy day midsayap pumutok simbahan day magbiy...
# 2017 1   2017, Jan.   kindly sit salamat secretary delfin lorenzana...
#      2   2017, Feb.   dureza naka raise konting pera akala ma relea...
#      3   2017, Mar.    salamat sit excellencies diplomatic corps pa...
#      4   2017, Apr.    excellency president joko widodo madame iria...
#      5    2017, May    kindly sit thank secretary delfin lorenzana;...
#      6   2017, Jun.     im glad tonight  enemy contend resistance f...
#      7   2017, Jul.   kindly sit thank courtesy read prepared speec...
#      8   2017, Aug.   pages need longer time start rattling cabinet...
#      9   2017, Sep.   kindly sit thank courtesy came hundreds miles...
#      10  2017, Oct.   prime minister abe committed flesh japans spe...
#      11  2017, Nov.   nandoon medyo matagalan amoy bagoong boodle s...
# 2018 1   2018, Jan.   kindly sit assalamualaikum maraming salamat p...
#      2   2018, Feb.   time maybe alongside mass surrenders ferocity...
#      3   2018, Mar.   thank courtesy kindly sit prepared speech pag...
#      4   2018, Apr.   clear relations larger community nations asea...
#      5    2018, May   salamat kindly sit pages mul billion investme...
#      6   2018, Jun.   maraming salamat kindly standing sit sitting ...
#      7   2018, Jul.   salamat courtesy kindly sit good written spee...
#      8   2018, Aug.   daghang salamat  kindly sit thank courtesy pr...
#      9   2018, Sep.   commander tikas pahinga order requested thank...
#      10  2018, Oct.   kindly sit salamat kortesiya naa koy pages sp...
#      11  2018, Nov.   kauban gobyerno bobby; asawa; opisyales diri ...
#      12  2018, Dec.   salamat kindly sit agrarian reform secretary ...
# 2019 1   2019, Jan.   magandang hapon sinadya pupunta maynila diver...
#      2   2019, Feb.   salamat kindly sit thank id like talk penchan...
#      3   2019, Mar.   kindly sit thank excellencies diplomatic corp...
#      4   2019, Apr.   nandito sigurado education secretary leonor b...
#      5    2019, May   nikkei president naotoshi okada excellencies ...
#      6   2019, Jun.   salamat kindly seats page prepared speech bab...
#      7   2019, Jul.   kindly sit magandang hapon magandang gabi pal...
#      8   2019, Aug.   ndyour excellency pleased undertake visit cor...
#      9   2019, Sep.   xiè xie kindly sit trade industry secretary r...
#      10  2019, Oct.     start question   yes   taking bangkok tomor...
#      11  2019, Nov.   salamat magsiupo sit think time grace occasio...
#      12  2019, Dec.   kindly sit sorry looking social welfare devel...
# 2020 1   2020, Jan.   sit salamat house speaker alan peter cayetano...
#      2   2020, Feb.   kindly sit salamat late pasig maka lantsa com...
#      3   2020, Mar.   ikatlong linggo pakigbisog formidable enemy s...
#      4   2020, Apr.   ahead yes berna good evening countrymen nagpa...
#      5    2020, May   bong mayorship days moment bong right nasabi ...
#      6   2020, Jun.     let start discussing issues affecting healt...
#
#          num_trans
# 2016 6           1
#      7          21
#      8          29
#      9          35
#      10         30
#      11         22
#      12         42
# 2017 1          19
#      2          21
#      3          32
#      4          32
#      5          25
#      6          24
#      7          18
#      8          18
#      9          23
#      10          5
#      11         17
# 2018 1           9
#      2          19
#      3          16
#      4          23
#      5          23
#      6          19
#      7          12
#      8          14
#      9          19
#      10         13
#      11         15
#      12         13
# 2019 1           9
#      2          13
#      3          14
#      4          13
#      5           9
#      6          12
#      7          13
#      8          11
#      9           9
#      10         10
#      11          7
#      12         11
# 2020 1          14
#      2           9
#      3          10
#      4          10
#      5           7
#      6           1

# %% [markdown]
# >Let's plot it

# %%
plt.figure(figsize=(15, 8))
plt.bar(range(df_months.shape[0]), df_months.num_trans, alpha=0.5)
plt.ylabel('Count', fontdict={'fontsize':12})
plt.xlabel('Date', fontdict={'fontsize':12}, labelpad=30)
lbl = [x[6:].strip() for x in df_months.date_str.tolist()]
plt.xticks(range(df_months.shape[0]), lbl, rotation=90)
# plt.text(x=10, y=42, s='Number of Transcripts collected over the months.', fontdict={'fontsize':20})
plt.title('Number of Transcripts collected monthly basis', fontdict={'fontsize':20})
# plt.text(-1, 70, 'Number of times Duterte utter the word    \nmonthly basis.',fontdict={'fontsize': 20})
# plt.text(23.5, 73, '"Bong"',  fontdict={'fontsize':23, 'color':'green'})

total = 0
for i in df_years.index.values:
    val = df_years.loc[i, 'num_months']
    total += val
    offset = (total / df_months.shape[0]) - 0.01
    line = plt.Line2D([offset,offset], [-0.12, 0], transform=plt.gca().transAxes, color='black')
    line.set_clip_on(False)
    plt.gca().add_line(line)
    plt.text(total - (val * 0.5), -5, i,  horizontalalignment='center', verticalalignment='center',
                clip_on=False)
# plt.add_line(line)
# plt.axvline(x=4+0.1, ymin=0.4)
#temps
plt.xlim(0, df_months.shape[0])
sns.despine()
plt.subplots_adjust(bottom=0.2)
# plt.savefig('pictures\\Number_Transcripts_Months.png')
plt.show()

# %% [markdown]
# ## 1.4 Total Number of Words <div id='section14'> </div>

# %%
df_all
# Out:
#     num_transcript                                       concat_trans
# all            791   pati bong mayorship days moment bong right na...

# %%
total_num_words = len(remove_stop(df_all.concat_trans.values[0]).split(' '))
df_all['num_words'] = total_num_words
print(f'Total Number of words: {total_num_words: ,}')
# Out:
# Total Number of words:  1,064,390

# %%
df_all
# Out:
#     num_transcript                                       concat_trans  \
# all            791   pati bong mayorship days moment bong right na...
#
#      num_words
# all    1064390

# %% [markdown]
# ***

# %% [markdown]
# # 2. WordCloud <div id='section2'> </div>
#
# >These are just the most common word used thoruhgout the timeline. The bigger the fontsize of the words the higher the count. Nothing really interesting here since the same words keep appearing other than in 2020 where the word 'covid' started to appear.

# %% [markdown]
# ## 2.1 Word Cloud of All collected Transcripts <div id='section21'> </div>

# %%
plt.figure(figsize=(10, 12))
create_word_cloud(data=df_all.concat_trans.values[0])
# plt.savefig('pictures\\Word_Cloud_All.png')

# %% [markdown]
# ## 2.2 Word Cloud of Year 2016 Transcripts <div id='section22'> </div>

# %%
plt.figure(figsize=(10, 12))
create_word_cloud(data=df_years.loc[2016, 'concat_trans'])
plt.title('2016 Word Cloud', size = 15)
# plt.savefig('pictures\\Word_Cloud_2016.png')
# Out:
# Text(0.5, 1.0, '2016 Word Cloud')

# %% [markdown]
# ## 2.3 Word Cloud of Year 2017 Transcripts <div id='section23'> </div>

# %%
plt.figure(figsize=(10, 12))
create_word_cloud(data=df_years.loc[2017, 'concat_trans'])
plt.title('2017 Word Cloud', size = 15)
# plt.savefig('pictures\\Word_Cloud_2017.png')
# Out:
# Text(0.5, 1.0, '2017 Word Cloud')

# %% [markdown]
# ## 2.4 Word Cloud of Year 2018 Transcripts <div id='section24'> </div>

# %%
plt.figure(figsize=(10, 12))
create_word_cloud(data=df_years.loc[2018, 'concat_trans'])
plt.title('2018 Word Cloud', size = 15)
# plt.savefig('pictures\\Word_Cloud_2018.png')
# Out:
# Text(0.5, 1.0, '2018 Word Cloud')

# %% [markdown]
# ## 2.5 Word Cloud of Year 2019 Transcripts <div id='section25'> </div>

# %%
plt.figure(figsize=(10, 12))
create_word_cloud(data=df_years.loc[2019, 'concat_trans'])
plt.title('2019 Transcripts\' Word Cloud', size = 15)
# plt.savefig('pictures\\Word_Cloud_2019.png')
# Out:
# Text(0.5, 1.0, "2019 Transcripts' Word Cloud")

# %% [markdown]
# ## 2.6 Word Cloud of Year 2020 Transcripts <div id='section26'> </div>

# %%
plt.figure(figsize=(10, 12))
create_word_cloud(data=df_years.loc[2020, 'concat_trans'])
plt.title('2020 Transcripts\' Word Cloud', size = 15)
# plt.savefig('pictures\\Word_Cloud_2020.png')
# Out:
# Text(0.5, 1.0, "2020 Transcripts' Word Cloud")

# %% [markdown]
# ___

# %% [markdown]
# # 3 DU30's Mouth Priority <div id='section3'> </div>

# %% [markdown]
# ## 3.1 Health, Educaiton, Safety, Love, Stability, Prosperity, Peace, Kill, Putangina <div id='section31'> </div>
# >We're just going to perform a word count for these words. The word 'putangina' is written in many ways that is why I separated the many ways they are written by the character '|'.

# %%
key_word = ['health',  'environment', 'education', 
            'economy', 'security',  'terrorism', 'peace', 
            'love', 'kill',  
            'p***** i** | p******** | p*****i** | p*** | putang ina | putangina | p****** i**'] 
#for some reason the type writer excess by one asterisk for the word 'putang'
words = ['health', 'environment', 'education', 
         'economy', 'security', 'terrorism', 
        'peace', 'love', 'kill', 'putang_ina']
for word, key in zip(words, key_word):
    df_all[f'{word}_freq'] = count_num_occur_multi_keys(df_all.concat_trans.values[0], key)
df_all.T
# Out:
#                                                                    all
# num_transcript                                                     791
# concat_trans          bong mayorship days moment bong right nasabi ...
# kill_freq                                                         1220
# health_freq                                                        339
# education_freq                                                     234
# patayin_freq                                                       688
# kalusugan_freq                                                       1
# edukasyon_freq                                                      85
# cayetano_freq                                                      113
# floirendo_freq                                                      18
# uy_freq                                                             79
# te_freq                                                             48
# safety_freq                                                        138
# love_freq                                                          336
# kaligtasan_freq                                                      0
# mahal_freq                                                         275
# putang_ina_freq                                                   1832
# tan_freq                                                           409
# alcantara_freq                                                      10
# mendoza_freq                                                        12
# regino_freq                                                          0
# gago_freq                                                          597
# tangina_freq                                                       427
# fuck_freq                                                          175
# shit_freq                                                          256
# bitch_freq                                                         168
# dick_freq                                                           56
# bullshit_freq                                                       86
# puta_freq                                                          426
# yawa_freq                                                          536
# stability_freq                                                      82
# prosperity_freq                                                     98
# security_freq                                                      707
# peace_freq                                                         939
# climate_change_freq                                                180
# environment_freq                                                   218
# economy_freq                                                       251
# terrorismpeace_freq                                                414
# terrorism_freq                                                     414
# kapaligiran_freq                                                     0
# ekonomiya_freq                                                      58
# seguridad_freq                                                       0
# terorismo_freq                                                      19
# kapayapaan_freq                                                     51

# %%
words = ['health', 'environment', 'education', 
         'economy', 'security', 'terrorism',
         'peace', 'love', 'kill']
colors = ['green', '#44ff6d', 'blue', 
          '#ffcc24','cyan', 'black', 
          'grey', 'violet', 'red', 'orange']
counts = [df_all[f'{x}_freq'].values[0] for x in words]
words.append('Putang Ina')
counts.append(df_all['putang_ina_freq'].values[0])

#format properly
words = [x.title() for x in words]
#sort them
sort_index = np.array(counts).argsort()
words = [words[i] for i in sort_index]
counts = [counts[i] for i in sort_index]
colors = [colors[i] for i in sort_index]
# colors = list(np.full((len(words)), 'blue'))

#plot
plt.figure(figsize=(20, 8))
plt.bar(range(len(words)), counts, color=colors, alpha=0.5)
plt.ylabel('Count', fontdict={'fontsize':18})
plt.xticks(range(len(words)), words, size=15)

#show number
show_number(counts, x_offset=-0.2, y_offset=+10, colors=colors, fontdict={'fontsize':17})

#Text Title
plt.text(-0.6, 1650, 'DUTERTE\'S MOUTH PRIORITY (english)', size=30)
plt.text(0, 1200, 'Number of times he utter these words.', size=13)


#percentage
sm = sum(counts)
percentage = [ str(int(round((x / sm) * 100, 0))) + '%' for x in counts]
show_number(np.zeros(len(words)) + 100, percentage, x_offset=-0.1, y_offset=-80, fontdict={'fontsize':15, 'alpha':0.6})

percent = str(sum([int(round((x / sm) * 100, 0)) for x in counts[:5]]))
# plt.text(-0.45, sum(counts[:5]) - 50, f'Environment + Education + Economy + Love + Health  ({percent}%)', \
#          fontdict={'color':'grey'}, alpha=1)
# plt.axhline(sum(counts[:5]), color='grey', linestyle='--', alpha=0.6)
sns.despine()
plt.gcf().subplots_adjust(left=0.16)
# plt.savefig('pictures\\Num_Health_Educaiton_Safety_Love_Kill_Putang_All.png')
plt.show()

# %%
words = ['health', 'education', 'kill']
plt.figure(figsize=(18, 10))
#PLOTTING

# plt.plot(xticks, df_months.health_freq.values, label='Health', c='green', alpha=0.5)
# plt.plot(xticks, df_months.education_freq.values, label='Education', c='blue', alpha=0.5)
# plt.plot(xticks, df_months.kill_freq.values, label='Kill', c='red', alpha=0.5)
width = 0.3
plt.bar(xticks, df_months.health_freq.values, label='Health', color='green', alpha=0.5, width=width)
plt.bar(xticks+width, df_months.kill_freq.values, label='Kill', color='red', alpha=0.5, width=width)
plt.bar(xticks-width, df_months.education_freq.values, label='Education', color='blue', alpha=0.5, width=width)



#TITLE
title = ['Number of times PRRD mentioned the word ','"', 'Health', '"', ', ','"',  'Education', '"', ',']
colors = ['black', 'black2', 'green', 'black2', 'black', 'black2', 'blue', 'black2', 'black']
sizes, colors = get_size_color(colors=colors, size_black=20, size_others=23)
rainbow_text(1, 104, strings=title, size=sizes, colors=colors)

text = ['and ', '"', 'Kill', '"', ' monthly basis.']
colors = ['black', 'black2', 'red', 'black2', 'black']
sizes, colors = get_size_color(colors=colors, size_black=20, size_others=23)
rainbow_text(7, 100, strings=text, size=sizes, colors=colors)
total = 0
for i in df_years.index.values:
    val = df_years.loc[i, 'num_months']
    total += val
    offset = (total / df_months.shape[0]) - 0.01
    line = plt.Line2D([offset,offset], [-0.08, 0], transform=plt.gca().transAxes, color='black')
    line.set_clip_on(False)
    plt.gca().add_line(line)
    plt.text(total - (val * 0.5), -8, i,  horizontalalignment='center', verticalalignment='center',
                clip_on=False)

#
plt.ylim(0, 100)
plt.xlim(0, len(xticks))
plt.legend(loc='best')
lbl = [x[6:].strip() for x in df_months.date_str.tolist()]
plt.xticks(range(df_months.shape[0]), lbl, rotation=90)
plt.xlabel('Months', labelpad=30)
plt.ylabel('Count')
sns.despine()
# plt.savefig('pictures\\Num_Health_Education_Kill_Months.png')
plt.show()

# %% [markdown]
# ## 3.2 Kalusugan,  Edukasyon, Kaligtasan, Mahal, Patayin, Putangina <div id='section32'> </div>

# %%
words = ['kalusugan', 'kapaligiran', 'edukasyon', 
         'ekonomiya', 'seguridad', 'terorismo',
        'kapayapaan', 'mahal', 'patayin']
for word in words:
    df_all[f'{word}_freq'] = df_all.concat_trans.apply(lambda x: count_num_occur(x, word))
df_all.T
# Out:
#                                                                    all
# num_transcript                                                     791
# concat_trans          bong mayorship days moment bong right nasabi ...
# kill_freq                                                         1220
# health_freq                                                        339
# education_freq                                                     234
# patayin_freq                                                       688
# kalusugan_freq                                                       1
# edukasyon_freq                                                      85
# cayetano_freq                                                      113
# floirendo_freq                                                      18
# uy_freq                                                             79
# te_freq                                                             48
# safety_freq                                                        138
# love_freq                                                          336
# kaligtasan_freq                                                      0
# mahal_freq                                                         275
# putang_ina_freq                                                   1574
# tan_freq                                                           409
# alcantara_freq                                                      10
# mendoza_freq                                                        12
# regino_freq                                                          0
# gago_freq                                                          597
# tangina_freq                                                       427
# fuck_freq                                                          175
# shit_freq                                                          256
# bitch_freq                                                         168
# dick_freq                                                           56
# bullshit_freq                                                       86
# puta_freq                                                          426
# yawa_freq                                                          536
# stability_freq                                                      82
# prosperity_freq                                                     98
# security_freq                                                      707
# peace_freq                                                         939
# climate_change_freq                                                180
# environment_freq                                                   218
# economy_freq                                                       251
# terrorismpeace_freq                                                414
# terrorism_freq                                                     414
# kapaligiran_freq                                                     0
# ekonomiya_freq                                                      58
# seguridad_freq                                                       0
# terorismo_freq                                                      19
# kapayapaan_freq                                                     51

# %% [markdown]
# >Let's plot it

# %%
words = ['kalusugan', 'kapaligiran', 'edukasyon', 
         'ekonomiya', 'seguridad', 'terorismo',
        'kapayapaan', 'mahal', 'patayin']
colors = ['green', '#44ff6d', 'blue', 
          '#ffcc24','cyan', 'black', 
          'grey', 'violet', 'red', 'orange']
counts = [df_all[f'{x}_freq'].values[0] for x in words]
words.append('Putang Ina')
counts.append(df_all['putang_ina_freq'].values[0])

#format properly
words = [x.title() for x in words]
#sort them
sort_index = np.array(counts).argsort()
words = [words[i] for i in sort_index]
counts = [counts[i] for i in sort_index]
colors = [colors[i] for i in sort_index]
# colors = list(np.full((len(words)), 'blue'))

#plot
plt.figure(figsize=(20, 10))
plt.bar(range(len(words)), counts, color=colors, alpha=0.5)
plt.ylabel('Count', fontdict={'fontsize':18})
plt.xticks(range(len(words)), words, size=15)

#show number
show_number(counts, x_offset=-0.2, y_offset=+10, colors=colors, fontdict={'fontsize':17})

#Text Title
plt.text(-0.6, 1650, 'DUTERTE\'S MOUTH PRIORITY (filipino)', size=30)
plt.text(0, 1200, 'I used google to translate Health, Environment, Education, \n\
Economy, Security, Terrorism, Peace, Love,and Kill', size=13)


#percentage
sm = sum(counts)
percentage = [ str(int(round((x / sm) * 100, 0))) + '%' for x in counts]
# show_number(np.zeros(len(words)) + 100, percentage, x_offset=-0.1, y_offset=-80, fontdict={'fontsize':15, 'alpha':0.6})

percent = str(sum([int(round((x / sm) * 100, 0)) for x in counts[:5]]))
# plt.text(-0.45, sum(counts[:5]) - 50, f'Environment + Education + Economy + Love + Health  ({percent}%)', \
#          fontdict={'color':'grey'}, alpha=1)
# plt.axhline(sum(counts[:5]), color='grey', linestyle='--', alpha=0.6)
sns.despine()
plt.gcf().subplots_adjust(left=0.16)
# plt.savefig('pictures\\Num_Health_Educaiton_Safety_Love_Kill_Putang_All.png')
plt.show()

# %% [markdown]
# ## 3.3 Combine <div id='section33'> </div>

# %%
words_fil = ['kalusugan', 'kapaligiran', 'edukasyon', 
         'ekonomiya', 'seguridad', 'terorismo',
        'kapayapaan', 'mahal', 'patayin']
words_eng = ['health', 'environment', 'education', 
         'economy', 'security', 'terrorism',
         'peace', 'love', 'kill']
colors = ['green', '#44ff6d', 'blue', 
          '#ffcc24','cyan', 'black', 
          'grey', 'violet', 'red', 'orange']

#Add counts of english words and its corresponding filipino words
counts = [df_all[f'{x}_freq'].values[0] + df_all[f'{y}_freq'].values[0]  for x, y in zip(words_fil, words_eng)]

#Append 'putang ina'
words_eng.append('Putang Ina')
counts.append(df_all['putang_ina_freq'].values[0])

#Format words properly
words_eng = [x.title() for x in words_eng]

#Sort data
sort_index = np.array(counts).argsort()
words_eng = [words_eng[i] for i in sort_index]
colors = [colors[i] for i in sort_index]
counts = sorted(counts)

#PLOT
plt.figure(figsize=(20, 10))
plt.bar(range(len(words_eng)), counts, color=colors, alpha=0.5)
plt.xticks(range(len(words_eng)), words_eng, size=15)

#Show Count
show_number(counts, x_offset=-0.2, y_offset=+10, colors=colors, fontdict={'fontsize':17})

#Show Percentage
sm = sum(counts)
percentage = [str(int(round(x / sm * 100, 0))) + '%' for x in counts]
show_number(np.full((len(percentage)), 100), words=percentage, x_offset=-0.1, 
            y_offset=-80, fontdict={'fontsize':15, 'alpha':0.6})

#Text Title
plt.text(-0.6, 2100, 'DUTERTE\'S MOUTH PRIORITY', size=30)
plt.text(0, 1500, "Number of times he uttered these words. \n\
I added the count of  their filipino translation\n\
(using google translate) except for 'putang ina'.", size=15)



sns.despine()
# plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.1))
plt.subplots_adjust(bottom=0.2)
# plt.savefig('pictures\\Kalusugan_Edukasyon_Kaligtasan_Mahal_Patayin_Putang_All.png')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 4. Countries Frequently Mentioned <div id='section4'> </div>
# >Let's see his most mentioned country. Load the names of countries first.

# %%
df_countries = pd.read_csv('Other Data\\countries.csv')
df_countries
# Out:
#     CCA2                  Name CCA3         Nationality
# 0     AD               Andorra  AND            Andorran
# 1     AE  United Arab Emirates  ARE             Emirati
# 2     AF           Afghanistan  AFG              Afghan
# 3     AG   Antigua and Barbuda  ATG  Antiguan, Barbudan
# 4     AI              Anguilla  AIA          Anguillian
# ..   ...                   ...  ...                 ...
# 256   YE                 Yemen  YEM              Yemeni
# 257   YT               Mayotte  MYT              French
# 258   ZA          South Africa  ZAF       South African
# 259   ZM                Zambia  ZMB             Zambian
# 260   ZW              Zimbabwe  ZWE          Zimbabwean
#
# [261 rows x 4 columns]

# %%
df_countries['name_lower'] = df_countries.Name.str.lower()
df_countries
# Out:
#     CCA2                  Name CCA3         Nationality            name_lower
# 0     AD               Andorra  AND            Andorran               andorra
# 1     AE  United Arab Emirates  ARE             Emirati  united arab emirates
# 2     AF           Afghanistan  AFG              Afghan           afghanistan
# 3     AG   Antigua and Barbuda  ATG  Antiguan, Barbudan   antigua and barbuda
# 4     AI              Anguilla  AIA          Anguillian              anguilla
# ..   ...                   ...  ...                 ...                   ...
# 256   YE                 Yemen  YEM              Yemeni                 yemen
# 257   YT               Mayotte  MYT              French               mayotte
# 258   ZA          South Africa  ZAF       South African          south africa
# 259   ZM                Zambia  ZMB             Zambian                zambia
# 260   ZW              Zimbabwe  ZWE          Zimbabwean              zimbabwe
#
# [261 rows x 5 columns]

# %% [markdown]
# >We're going to traverse through this and count the occurences in the transcript

# %%
freq_countries = []
for country in df_countries.name_lower.values:
    freq_countries.append(count_num_occur(df_all.concat_trans.values[0], country))
df_countries['country_freq'] = freq_countries
df_countries
# Out:
#     CCA2                  Name CCA3         Nationality            name_lower  \
# 0     AD               Andorra  AND            Andorran               andorra
# 1     AE  United Arab Emirates  ARE             Emirati  united arab emirates
# 2     AF           Afghanistan  AFG              Afghan           afghanistan
# 3     AG   Antigua and Barbuda  ATG  Antiguan, Barbudan   antigua and barbuda
# 4     AI              Anguilla  AIA          Anguillian              anguilla
# ..   ...                   ...  ...                 ...                   ...
# 256   YE                 Yemen  YEM              Yemeni                 yemen
# 257   YT               Mayotte  MYT              French               mayotte
# 258   ZA          South Africa  ZAF       South African          south africa
# 259   ZM                Zambia  ZMB             Zambian                zambia
# 260   ZW              Zimbabwe  ZWE          Zimbabwean              zimbabwe
#
#      country_freq
# 0               0
# 1               0
# 2              10
# 3               0
# 4               0
# ..            ...
# 256             3
# 257             0
# 258             0
# 259             1
# 260             0
#
# [261 rows x 6 columns]

# %%
df_countries.nlargest(n=10, columns='country_freq')
# Out:
#     CCA2         Name CCA3  Nationality   name_lower  country_freq
# 185   PH  Philippines  PHL     Filipino  philippines          2344
# 48    CN        China  CHN      Chinese        china          1502
# 201   RU       Russia  RUS      Russian       russia           286
# 104   ID    Indonesia  IDN   Indonesian    indonesia           278
# 117   JP        Japan  JPN     Japanese        japan           258
# 163   MY     Malaysia  MYS    Malaysian     malaysia           253
# 150   ML         Mali  MLI       Malian         mali           173
# 110   IQ         Iraq  IRQ        Iraqi         iraq           142
# 208   SG    Singapore  SGP  Singaporean    singapore           119
# 127   KW       Kuwait  KWT      Kuwaiti       kuwait           114

# %% [markdown]
# >So these are the top 10 most frequent mentioned countries, you migh be surprised that USA is not part of this list. Well because in this list its name is  'United States' which our algorithm was not able to detect because we only used 1 word for counting number or occurences and PRRD usually use 'usa' to refer to these countires. So instead of  these names we'll use 'usa'. Russia also has other name which is the Russian Federation so I have to include this as its name.We'll add those names to the name_lower features. We'll also use another algorithm for multiple words name.

# %%
df_countries[df_countries.Name == 'United States']
# Out:
#     CCA2           Name CCA3 Nationality     name_lower  country_freq
# 242   US  United States  USA    American  united states             0

# %%
df_countries.loc[242, 'name_lower']  = df_countries.loc[242, 'name_lower'] + " | usa"
df_countries.loc[242, 'name_lower']
# Out:
# 'united states | usa'

# %%
df_countries.loc[201, 'name_lower'] = 'russian federation | ' + df_countries.loc[201, 'name_lower']
df_countries.loc[201, 'name_lower']
# Out:
# 'russian federation | russia'

# %% [markdown]
# >Let's create a function that counts the number of occurences of country

# %%
def count_num_occur_multi_keys(target, keys):
    names = keys
    count = 0

    #first find if contain multiple names
    if keys.find('|') != -1:
        names = [x.strip() for x in keys.split('|')]
        for name in names:
            count += count_num_occur(target, name.split(' '))
    else:
        count = count_num_occur(target, keys.split(' '))
        
    return count

# %% [markdown]
# >Now let's count the number of occurences again.

# %%
df_countries['country_freq'] = df_countries.name_lower.apply(lambda x:  \
                                                             count_num_occur_country(df_all.concat_trans.values[0], x))
df_countries
# Out:
#     CCA2                  Name CCA3         Nationality            name_lower  \
# 0     AD               Andorra  AND            Andorran               andorra
# 1     AE  United Arab Emirates  ARE             Emirati  united arab emirates
# 2     AF           Afghanistan  AFG              Afghan           afghanistan
# 3     AG   Antigua and Barbuda  ATG  Antiguan, Barbudan   antigua and barbuda
# 4     AI              Anguilla  AIA          Anguillian              anguilla
# ..   ...                   ...  ...                 ...                   ...
# 256   YE                 Yemen  YEM              Yemeni                 yemen
# 257   YT               Mayotte  MYT              French               mayotte
# 258   ZA          South Africa  ZAF       South African          south africa
# 259   ZM                Zambia  ZMB             Zambian                zambia
# 260   ZW              Zimbabwe  ZWE          Zimbabwean              zimbabwe
#
#      country_freq
# 0               0
# 1               1
# 2              10
# 3               0
# 4               0
# ..            ...
# 256             3
# 257             0
# 258             6
# 259             1
# 260             0
#
# [261 rows x 6 columns]

# %% [markdown]
# >Let's see the top 10

# %%
df_countries.nlargest(n=10, columns='country_freq', keep='all')
# Out:
#     CCA2           Name CCA3  Nationality                   name_lower  \
# 185   PH    Philippines  PHL     Filipino                  philippines
# 48    CN          China  CHN      Chinese                        china
# 242   US  United States  USA     American          united states | usa
# 201   RU         Russia  RUS      Russian  russian federation | russia
# 104   ID      Indonesia  IDN   Indonesian                    indonesia
# 117   JP          Japan  JPN     Japanese                        japan
# 163   MY       Malaysia  MYS    Malaysian                     malaysia
# 150   ML           Mali  MLI       Malian                         mali
# 110   IQ           Iraq  IRQ        Iraqi                         iraq
# 208   SG      Singapore  SGP  Singaporean                    singapore
#
#      country_freq
# 185          2344
# 48           1502
# 242           598
# 201           298
# 104           278
# 117           258
# 163           253
# 150           173
# 110           142
# 208           119

# %% [markdown]
# >These are the top 10 countries he frequently mentioned. He also mentioned 'america' but I will not include it in the list since it could refer to north or/and south america but we'll include it in the plot.

# %%
2344 / df_countries.country_freq.sum()
# Out:
# 0.30668585633913387

# %%
counts = df_countries.nlargest(n=10, columns='country_freq', keep='all')['country_freq'].values.tolist()
names = df_countries.nlargest(n=10, columns='country_freq', keep='all')['Name'].values.tolist()
names[2] = 'USA|' + names[2]
names[3] = names[3] + '|Russian Federation'

#Plot
plt.figure(figsize=(15,8))
plt.barh(range(len(counts)), counts, alpha=0.5)

#USA additional plot

#united statates america count
united_states_america_count = count_num_occur(df_all.concat_trans.values[0], ['united', 'states', 'america'])

#I have to deduct united_states_america_count since "united states america" had already beeen counted
#from counting "united states"
america_count = count_num_occur(df_all.concat_trans.values[0], 'america') - united_states_america_count
#amerika count
amerika_count = count_num_occur(df_all.concat_trans.values[0], 'amerika')

#usa + america + amerika count
plt.yticks(range(len(counts)), names, size=12)
usa_count = america_count + amerika_count + counts[2]
plt.barh(2, usa_count, color='grey', alpha=0.1)
plt.text(usa_count+10,1.98, s=usa_count, color='grey', alpha=0.8)

#Show count
show_number(counts, orientation='hotizontal',x_offset=5,fontdict={'fontsize':12})

#Show percentage
sm = df_countries.country_freq.sum()
percentage = [str(int(round(x / sm * 100, 0))) + '%' for x in counts]
show_number(np.full((len(percentage)), 10,), percentage, orientation='horizontal', 
           y_offset=-0.15, fontdict={'fontsize':14, 'alpha':0.6})
sm_america_amerika = sm + america_count + amerika_count
percent_usa_america_amerika = str(int(round(usa_count / sm_america_amerika * 100, 0) )) + '%'
# plt.text(x=1000, y=1.95, s=percent_usa_america_amerika)

#Text Title
plt.title('Top 10 countries PRRD frequently mention', size=18)


#Text Body
plt.text(x=600, y=6, s=f'He uttered a total of {sm:,} countries\' name . Other than the Philippines the most frequent country\n\
he mentioned was China. That is if we don\'t consider the word "America" and "Amerika" \n\
(prob. spelling error) as USA which he mentioned {america_count} and {amerika_count} respectively.\n\
If we do consider, this would bring our total to {sm_america_amerika:,} countries\' name and \n\
USA being the most frequent other than Philippines.' , fontdict={'fontsize':12})
# plt.text(x=600, y =8, s=f'He also mentioned "America" {america_count} times but didn\'t include it here.',
#         fontdict={'fontsize':12, 'color':'blue'})
plt.text(x=1100, y=1.95, s='USA + United States + America + Amerika')

sns.despine()
plt.xlabel('Count')
# plt.savefig('pictures\\Num_Top_Countries_All.png')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 5. Nationality  Frequently Mentioned <div id='section5'> </div>

# %%
df_countries
# Out:
#     CCA2                  Name CCA3         Nationality            name_lower  \
# 0     AD               Andorra  AND            Andorran               andorra
# 1     AE  United Arab Emirates  ARE             Emirati  united arab emirates
# 2     AF           Afghanistan  AFG              Afghan           afghanistan
# 3     AG   Antigua and Barbuda  ATG  Antiguan, Barbudan   antigua and barbuda
# 4     AI              Anguilla  AIA          Anguillian              anguilla
# ..   ...                   ...  ...                 ...                   ...
# 256   YE                 Yemen  YEM              Yemeni                 yemen
# 257   YT               Mayotte  MYT              French               mayotte
# 258   ZA          South Africa  ZAF       South African          south africa
# 259   ZM                Zambia  ZMB             Zambian                zambia
# 260   ZW              Zimbabwe  ZWE          Zimbabwean              zimbabwe
#
#      country_freq   nationality_lower
# 0               0            andorran
# 1               1             emirati
# 2              10              afghan
# 3               0  antiguan, barbudan
# 4               0          anguillian
# ..            ...                 ...
# 256             3              yemeni
# 257             0              french
# 258             6       south african
# 259             1             zambian
# 260             0          zimbabwean
#
# [261 rows x 7 columns]

# %% [markdown]
# >Let's lower the nationality

# %%
df_countries['nationality_lower'] = df_countries.Nationality.str.lower()
df_countries
# Out:
#     CCA2                  Name CCA3         Nationality            name_lower  \
# 0     AD               Andorra  AND            Andorran               andorra
# 1     AE  United Arab Emirates  ARE             Emirati  united arab emirates
# 2     AF           Afghanistan  AFG              Afghan           afghanistan
# 3     AG   Antigua and Barbuda  ATG  Antiguan, Barbudan   antigua and barbuda
# 4     AI              Anguilla  AIA          Anguillian              anguilla
# ..   ...                   ...  ...                 ...                   ...
# 256   YE                 Yemen  YEM              Yemeni                 yemen
# 257   YT               Mayotte  MYT              French               mayotte
# 258   ZA          South Africa  ZAF       South African          south africa
# 259   ZM                Zambia  ZMB             Zambian                zambia
# 260   ZW              Zimbabwe  ZWE          Zimbabwean              zimbabwe
#
#      country_freq   nationality_lower
# 0               0            andorran
# 1               1             emirati
# 2              10              afghan
# 3               0  antiguan, barbudan
# 4               0          anguillian
# ..            ...                 ...
# 256             3              yemeni
# 257             0              french
# 258             6       south african
# 259             1             zambian
# 260             0          zimbabwean
#
# [261 rows x 7 columns]

# %%
df_countries[df_countries.nationality_lower == 'american']
# Out:
#     CCA2                         Name CCA3 Nationality  \
# 154   MP     Northern Mariana Islands  MNP    American
# 241   UM  U.S. Minor Outlying Islands  UMI    American
# 242   US                United States  USA    American
#
#                       name_lower  country_freq nationality_lower
# 154     northern mariana islands             0          american
# 241  u.s. minor outlying islands             0          american
# 242          united states | usa           598          american

# %%
df_countries[df_countries.nationality_lower == 'chinese']
# Out:
#     CCA2                 Name CCA3 Nationality           name_lower  \
# 48    CN                China  CHN     Chinese                china
# 98    HK  Hong Kong SAR China  HKG     Chinese  hong kong sar china
# 153   MO      Macau SAR China  MAC     Chinese      macau sar china
#
#      country_freq nationality_lower
# 48           1502           chinese
# 98              0           chinese
# 153             0           chinese

# %%
df_countries[df_countries.nationality_lower == '?']
# Out:
#     CCA2                                       Name CCA3 Nationality  \
# 9     AQ                                 Antarctica  ATA           ?
# 34    BV                              Bouvet Island  BVT           ?
# 52    CT               Canton and Enderbury Islands  CTE           ?
# 76    FQ  French Southern and Antarctic Territories  ATF           ?
# 78    FX                        Metropolitan France  FXX           ?
# 83    GF                              French Guiana  GUF           ?
# 118   JT                            Johnston Island  JTN           ?
# 174   NQ                         Dronning Maud Land  ATN           ?
# 176   NT                               Neutral Zone  NTZ           ?
# 181   PC            Pacific Islands Trust Territory  PCI           ?
# 193   PU         U.S. Miscellaneous Pacific Islands  PUS           ?
# 196   PZ                          Panama Canal Zone  PCZ           ?
# 219   SU        Union of Soviet Socialist Republics    ?           ?
# 247   VD                              North Vietnam  VDR           ?
# 254   WK                                Wake Island  WAK           ?
#
#                                     name_lower  country_freq nationality_lower
# 9                                   antarctica             0                 ?
# 34                               bouvet island             0                 ?
# 52                canton and enderbury islands             0                 ?
# 76   french southern and antarctic territories             0                 ?
# 78                         metropolitan france             0                 ?
# 83                               french guiana             0                 ?
# 118                            johnston island             0                 ?
# 174                         dronning maud land             0                 ?
# 176                               neutral zone             0                 ?
# 181            pacific islands trust territory             0                 ?
# 193         u.s. miscellaneous pacific islands             0                 ?
# 196                          panama canal zone             0                 ?
# 219        union of soviet socialist republics             0                 ?
# 247                              north vietnam             0                 ?
# 254                                wake island             0                 ?

# %% [markdown]
# >So some has the same nationality but we're going to treat them as one. There are also who has a question mark (?)  nationality so we'll exlude those. PRRD also sometimes refer to American as Americano  and Filipino as Pinoy so we'll include that in the list. He also refer to Japanese as Hapon but he could also be referring to 'hapon' as in 'afternoon'. We'll include also korean since in the list they are refered to as either north korean and south korean. Lastly we'll consider the plural form of these nationality by adding s as the last character.

# %%
grouped_count = df_countries.groupby('nationality_lower')
nationality_lt = list(grouped_count.groups.keys())[1:]
nationality_lt.remove('filipino')
nationality_lt.append('filipino | pinoy')
nationality_lt.remove('american')
nationality_lt.append('american | amerikano')
nationality_lt.remove('japanese')
nationality_lt.append('japanese | hapon')
nationality_lt.remove('chinese')
nationality_lt.append('chinese | intsik')
nationality_lt.remove('north korean')
nationality_lt.remove('south korean')
nationality_lt.append('korean')

print(nationality_lt)
# Out:
# ['afghan', 'albanian', 'algerian', 'american samoan', 'andorran', 'angolan', 'anguillian', 'antiguan, barbudan', 'argentinean', 'armenian', 'aruban', 'australian', 'austrian', 'azerbaijani', 'bahamian', 'bahraini', 'bangladeshi', 'barbadian', 'belarusian', 'belgian', 'belizean', 'beninese', 'bermudian', 'bhutanese', 'bolivian', 'bosnian, herzegovinian', 'brazilian', 'british', 'bruneian', 'bulgarian', 'burkinabe', 'burundian', 'cambodian', 'cameroonian', 'canadian', 'cape verdian', 'caymanian', 'central african', 'chadian', 'channel islander', 'chilean', 'christmas island', 'cocos islander', 'colombian', 'comoran', 'congolese', 'cook islander', 'costa rican', 'croatian', 'cuban', 'cypriot', 'czech', 'danish', 'djibouti', 'dominican', 'dutch', 'east timorese', 'ecuadorean', 'egyptian', 'emirati', 'equatorial guinean', 'eritrean', 'estonian', 'ethiopian', 'falkland islander', 'faroese', 'fijian', 'finnish', 'french', 'french polynesian', 'gabonese', 'gambian', 'georgian', 'german', 'ghanaian', 'gibraltar', 'greek', 'greenlandic', 'grenadian', 'guadeloupian', 'guamanian', 'guatemalan', 'guinea-bissauan', 'guinean', 'guyanese', 'haitian', 'heard and mcdonald islander', 'honduran', 'hungarian', 'i-kiribati', 'icelander', 'indian', 'indonesian', 'iranian', 'iraqi', 'irish', 'israeli', 'italian', 'ivorian', 'jamaican', 'jordanian', 'kazakhstani', 'kenyan', 'kirghiz', 'kittian and nevisian', 'kuwaiti', 'laotian', 'latvian', 'lebanese', 'liberian', 'libyan', 'liechtensteiner', 'lithuanian', 'luxembourger', 'macedonian', 'malagasy', 'malawian', 'malaysian', 'maldivan', 'malian', 'maltese', 'manx', 'marshallese', 'mauritanian', 'mauritian', 'mexican', 'micronesian', 'moldovan', 'monegasque', 'mongolian', 'montenegrin', 'montenegrins, serbs', 'montserratian', 'moroccan', 'mosotho', 'motswana', 'mozambican', 'myanmar', 'namibian', 'nauruan', 'nepalese', 'new caledonian', 'new zealander', 'ni-vanuatu', 'nicaraguan', 'nigerian', 'niuean', 'norfolk islander', 'norwegian', 'omani', 'pakistani', 'palauan', 'palestinian', 'panamanian', 'papua new guinean', 'paraguayan', 'peruvian', 'pitcairn islander', 'polish', 'portuguese', 'puerto rican', 'qatari', 'romanian', 'russian', 'rwandan', 'sahrawi', 'saint barthélemy islander', 'saint helenian', 'saint lucian', 'saint martin islander', 'saint vincentian', 'salvadoran', 'sammarinese', 'samoan', 'sao tomean', 'saudi arabian', 'senegalese', 'serbian', 'seychellois', 'sierra leonean', 'singaporean', 'slovak', 'slovene', 'solomon islander', 'somali', 'south african', 'south georgia and the south sandwich islander', 'spanish', 'sri lankan', 'sudanese', 'surinamer', 'swazi', 'swedish', 'swiss', 'syrian', 'tadzhik', 'taiwanese', 'tanzanian', 'thai', 'togolese', 'tokelauan', 'tongan', 'trinidadian', 'tunisian', 'turkish', 'turkmen', 'turks and caicos islander', 'tuvaluan', 'ugandan', 'ukrainian', 'uruguayan', 'uzbekistani', 'venezuelan', 'vietnamese', 'virgin islander', 'wallis and futuna islander', 'yemeni', 'zambian', 'zimbabwean', 'filipino | pinoy', 'american | amerikano', 'japanese | hapon', 'chinese | intsik', 'korean']

# %% [markdown]
# >Let's count the number of occurences of these words

# %%
freq_lt = []
for national in nationality_lt:
    count = count_num_occur_multi_keys(df_all.concat_trans.values[0], national)
    
    #plural
    if national.find('|') == -1:
        count += count_num_occur_multi_keys(df_all.concat_trans.values[0], national + 's') 
    else:
        national = national.split('|')
        national = ' | '.join([x.strip() + "s" for x in national])
        count += count_num_occur_multi_keys(df_all.concat_trans.values[0], national)
    freq_lt.append(count)
    
    
df_nationality = pd.DataFrame(index=nationality_lt, data={'nationality_freq':freq_lt})
df_nationality.reset_index(inplace=True)
df_nationality.rename(columns={'index':'name'}, inplace=True)
df_nationality
# Out:
#                      name  nationality_freq
# 0                  afghan                 0
# 1                albanian                 0
# 2                algerian                 0
# 3         american samoan                 0
# 4                andorran                 0
# ..                    ...               ...
# 219      filipino | pinoy              2075
# 220  american | amerikano              1021
# 221      japanese | hapon               195
# 222      chinese | intsik               695
# 223                korean                65
#
# [224 rows x 2 columns]

# %% [markdown]
# >Let's see the top 10

# %%
df_nationality.nlargest(n=10, columns='nationality_freq', keep='all')
# Out:
#                      name  nationality_freq
# 219      filipino | pinoy              2075
# 220  american | amerikano              1021
# 222      chinese | intsik               695
# 221      japanese | hapon               195
# 223                korean                65
# 92             indonesian                62
# 163               russian                62
# 187               spanish                54
# 91                 indian                49
# 117             malaysian                44

# %% [markdown]
# >These are the top nationality he frequently mention. Let's plot them.

# %%
df_nationality
# Out:
#                      name  nationality_freq
# 0                  afghan                 0
# 1                albanian                 0
# 2                algerian                 0
# 3         american samoan                 0
# 4                andorran                 0
# ..                    ...               ...
# 219      filipino | pinoy              2075
# 220  american | americano               591
# 221      japanese | hapon               195
# 222      chinese | intsik               695
# 223                korean                65
#
# [224 rows x 2 columns]

# %%
df_nationality.nationality_freq.sum()
# Out:
# 4648

# %%
plt.figure(figsize=(15,8))
counts = df_nationality.nlargest(n=10, columns='nationality_freq', keep='all')['nationality_freq'].values.tolist()
#format properly
names = []
for name in df_nationality.nlargest(n=10, columns='nationality_freq', keep='all')['name']:
    if name.find('|') == -1:
        names.append(name.title())
    else:
        lt = [nm.title().strip() for nm in name.split('|')]
        names.append('|'.join(lt))

plt.barh(range(len(counts)), counts, alpha=0.5)
plt.yticks(range(len(counts)), names, size=12)
show_number(counts, orientation='hotizontal',x_offset=5,fontdict={'fontsize':12})

united_states_america_count = count_num_occur(df_all.concat_trans.values[0], ['united', 'states', 'america'])
#I have to deduct united_states_america_count since "united states of america" had already beeen counted
#from counting "united states"
america_count = count_num_occur(df_all.concat_trans.values[0], 'america') - united_states_america_count

#Show percentage
sm = df_nationality.nationality_freq.sum()
percentage = [str(int(round(x / sm * 100, 0))) + '%' for x in counts]
show_number(np.full((len(percentage)), 5), percentage, orientation='horizontal', 
           y_offset=-0.15, fontdict={'fontsize':13, 'alpha':0.6})
# sm_america_amerika = sm + america_count + amerika_count
# percent_usa_america_amerika = str(int(round(usa_count / sm_america_amerika * 100, 0) )) + '%'

#Text Title
plt.title('Top 10 Nation PRRD frequently mention', size=18)
# plt.text(x=500, y=9.5,s='Top 10 countries PRRD frequently mention', fontdict={'fontsize':18})

amerika_count = count_num_occur(df_all.concat_trans.values[0], 'amerika')
amerikano_count = count_num_occur(df_all.concat_trans.values[0], 'amerikano')
plt.text(500, 7, f"He uttered a total of {sm:,} nationalities' name. I included the word \"Hapon\" for counting Japanese\n\
but he could be referring to hapon  meaning afternoon. For Korean he could be referring to North\n\
or South. I also considered their plural form when counting. Other than Filipino,\n\
American is the most frequent nationality metioned." , size=12)
sns.despine()
plt.xlabel('Count')
# plt.savefig('pictures\\Num_Top_Countries_All.png')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 6.  Frequently Mentioned Donors' last name <div section='section6'> </div>

# %%
words = ['floirendo', 'cayetano',  'te', 'uy', 'tan', 'alcantara', 'mendoza', 'regino']
for word in words:
    df_all[f'{word}_freq'] = count_num_occur(df_all.concat_trans.values[0], word)
df_all.T
# Out:
#                                                                all
# num_transcript                                                 791
# concat_trans      bong mayorship days moment bong right nasabi ...
# kill_freq                                                     1220
# health_freq                                                    339
# education_freq                                                 234
# patayin_freq                                                   688
# kalusugan_freq                                                   1
# edukasyon_freq                                                  85
# cayetano_freq                                                  113
# floirendo_freq                                                  18
# uy_freq                                                         79
# te_freq                                                         48
# safety_freq                                                    138
# love_freq                                                      336
# kaligtasan_freq                                                  0
# mahal_freq                                                     275
# putang_ina_freq                                               1829
# tan_freq                                                       409
# alcantara_freq                                                  10
# mendoza_freq                                                    12
# regino_freq                                                      0

# %% [markdown]
# >Let's plot them

# %%
plt.figure(figsize=(15,8))
words = ['floirendo', 'cayetano',  'te', 'uy', 'tan', 'alcantara', 'mendoza', 'regino']
counts = [df_all[f'{x}_freq'].values[0] for x in words]
words = [words[i] for i in np.array(counts).argsort()]
counts = sorted(counts)
plt.figure(figsize=(8, 5))
# counts = df_all.loc[:, ['cayetano_freq', 'floirendo_freq', 'te_freq', 'uy_freq']].values.tolist()[0]
plt.bar(range(len(words)), height=counts, alpha=0.5)
plt.xticks(range(len(words)), [x.upper() for x in words ], rotation=20)
show_number(counts=counts, y_offset=2, x_offset=-0.09, fontdict={'fontsize':12})
plt.title('Number of time he mentioned the last name of his top 10 donors', size=13)
sns.despine()
plt.ylim(0, 450)
plt.text(0, 350, 'Keep in mind that these are just the number of occurences of \nthese words he could be referring \
to another person or maybe \nan animal who knows...')
# plt.savefig('pictures\\Num_Top_Donors.png')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 7. Favorite swear words <div id='section7'> </div>
# >This is a tricky one, I looked at the transcripts and most of the swear words are censored. The censored one starts with the first letter of the word then followed by asterisk '\*'. For example the word 'puta' is replaced by p***. I'm going to find words that starts with a letter followed by asterisk and have a counter for these words.

# %%
count = 0
swear_dct = {}
for txt in df_all.concat_trans.values[0].split(" "):
    if '*' in txt:
        isSwear = False
        for i in txt:
            if i != '*':
                isSwear = True
        if isSwear:
            if txt in swear_dct.keys():
                swear_dct[txt] += 1
            else:
                swear_dct[txt] = 1
df_swear = pd.DataFrame(data={'words': list(swear_dct.keys()), 'counts':list(swear_dct.values())})
display(df_swear)
print('\nTop 10')
display(df_swear.nlargest(10, 'counts'))
# Out:
#          words  counts
# 0       p*****    1951
# 1          i**    2447
# 2        i****     428
# 3       g*****     101
# 4         p***     404
# ..         ...     ...
# 297   ehp*****       1
# 298   s***sige       1
# 299   a**huwag       1
# 300      f***s       1
# 301  taran****       1
#
# [302 rows x 2 columns]
# Top 10
#       words  counts
# 1       i**    2447
# 0    p*****    1951
# 6      t***     539
# 5      g***     532
# 2     i****     428
# 10     y***     413
# 4      p***     404
# 8   p******     338
# 26    p****     299
# 18    l****     232

# %% [markdown]
# >The result shows a lot of  swear words a total of 302 but if we look at the last swear words they are mostly those swear words at the top but written differently or concatenated to another word/character. Also the words "i***" or anything that start with i then followed by asterisk which I believe is "ina", 'inang' and so on is only a swear word if preceeded by "putang". The whole swear word is "putang ina" and should be considered as one count. I have to remove any words in df_swear that starts with 'i'.

# %%
i_swear_words = df_swear[df_swear.words.apply(lambda x: x[0] == 'i')]
i_swear_words
# Out:
#             words  counts
# 1             i**    2447
# 2           i****     428
# 14         i*****      68
# 20           i***      88
# 80        i******       1
# 143       i**yang       1
# 147            i*       3
# 149          i**)       1
# 164         i**mo       1
# 178       i**niya       1
# 181         i**ng      11
# 195      is******       1
# 197        i***ng       1
# 235      i**sigeg       1
# 237        il****       1
# 258   i**maniwala       1
# 259        i**mag       1
# 261  i**ipapakain       1
# 264     i**balita       1
# 270       i**buti       1
# 277  i**tinawagan       1
# 284      i**tapos       1

# %% [markdown]
# >So I have to remove all this.

# %%
df_swear.counts.sum()
# Out:
# 6765

# %%
df_swear.drop(index=i_swear_words.index.values, inplace=True)
df_swear.reset_index(drop=True, inplace=True)
print('Top 10')
display(df_swear.nlargest(10, 'counts'))
# Out:
# Top 10
#       words  counts
# 0    p*****    1951
# 4      t***     539
# 3      g***     532
# 8      y***     413
# 2      p***     404
# 6   p******     338
# 22    p****     299
# 15    l****     232
# 16     s***     228
# 11     f***     166

# %% [markdown]
# >There are a lot of swear words that start with p then followed by asterisk. I believe the first one is for "putang" second is "puta". The third one is a little bit tricky one, I looked at the transcrips and found out that most are followed by "i\*\*" which means it refers to "putang ina" it just that number of asterisk exceeded probably a human error. Some occurence also is just the word 'p\*\*\*\*\*\*' and not being followed by "ina" or "i\*\*". The could refer to the word "punyeta" or just "putang". If you look at the phrases below which are some of the occurence of this word it actualy make sense for it to be "putang" than punyeta.

# %%
find_occur(df_all.concat_trans.values[0], 'p******', num=30, offset=10)
# Out:
# [' p****** i** kayong youre b***s*** youre legal fronts kumukuha pera',
#  ' p****** i** huhubaran kita harap tao country comes mahal bayan',
#  ' p****** i** pitsugin trial tingnan id happy place cross witness',
#  ' p****** i**** pera term sign transaction papers reclamation railway belongs',
#  ' p****** i**** human rights ganun drug lord f*** ta hihinto',
#  ' p****** i** nagbabayad buwis hinihingian sampalin maski kayong t*** i**',
#  ' p****** i** harap harapan magnakaw rob blind',
#  ' p****** i** begin read speech id like greet everybody thank',
#  ' p****** i**** nakikinig buong bayan totoo destroy country destroy youth',
#  ' p****** i** makinig criminals kasalanan grieve blood tinitignan bumagsak tatay',
#  ' p****** mundo papasok utak sira ulo crave fix pera magnakaw',
#  ' p****** i** leni harap sampalin dalhin dare invite sinabi immigration',
#  ' p****** i** public p**** i** magnanakaw l*** ganon noticed sagot',
#  ' p****** i** celebrate y*** came country conquered subjugated filipinos slave',
#  ' p****** kulungin kulong bantay isahin violent ganun papayag nang babastusin',
#  ' p****** i**** retire p*****i*** ikulong l*** ganun pulis maam gago',
#  ' p****** i** lokohin police kaibigan mangyari totoo think help performance',
#  ' p****** i**** trillanes duwag problema pagka ganun tanungin ha kayong',
#  ' p****** i***** smartmatic mabuti sipain sirain sir harap science technology',
#  ' p****** i** finile kaso utos magsasabi nang totoo sabihan lie',
#  ' p****** i***** talagang morally bankrupt kill people bang mexicano ―señor',
#  ' p****** drugs bulsa fact huhulihin pagdating istasyon ibu book release',
#  ' p****** i** tapos ganon sakripisyo kang tulog gabi gabi alas',
#  ' p****** i** oo sige magpili kandidato administrasyon pakialam manalo tapos',
#  ' p****** i** nung presidente sinabi kayong ugok p***** i** nakinig',
#  ' p****** i** mong ganun pera using legitimate launder padaan hugasan',
#  ' p****** i** dare say drilon contract said republic republic philippines']

# %%
'putangina', 'tangina', 'gago', 'yawa', 'puta', 'putangina', 'putang', 'leche', 'shit', 'fuck', 'ugok', 'bitch', ''

# %%
len('p******')
# Out:
# 7

# %%
len('p******')
# Out:
# 7

# %%
len('Punyeta')
# Out:
# 7

# %%
len('l****')
# Out:
# 5

# %%
len('letse')
# Out:
# 5

# %%
len('p****')
# Out:
# 5

# %%
count_num_occur(df_all.concat_trans.values[0], 'buwisit')
# Out:
# 7

# %%
def find_word(target, key):
    for wrd in target.split(' '):
        if wrd == key:
            return True
    return False

# %%
df[df.transcript.apply(lambda x: any('p******' == wrd for wrd in x.split(' ')) )].url.values[0]
# Out:
# 'https://pcoo.gov.ph/presidential-speech/talk-to-the-people-of-president-rodrigo-roa-duterte-on-coronavirus-disease-2019-covid-19-3/'

# %%
keys = ['p*** | puta', 't***i** | t*** i** | tangina | tang ina' , 'g*** | gago', 'yawa | y***', 'f*** | fuck', 
        's*** | shit', 'b**** | bitch',  'd*** | dick', 'b***s*** | b*** s*** | bullshit | bull shit' ]
words = ['puta', 'tangina', 'gago', 'yawa', 'fuck', 'shit', 'bitch', 'dick', 'bullshit']

# %% [markdown]
# >There are words that were written/represented in transcript in two ways like the word 'tangina' which were written as 'tangina' and 'tang ina' (so putangina naman oh saan consistency dito). That's why I put the ways they were written in a single string that is separated by the character '|'. Now I just need to use the function *count_num_occur_multi_keys*.

# %%
for key, word in zip(keys, words):
    df_all[f'{word}_freq'] = count_num_occur_multi_keys(df_all.concat_trans.values[0], key)
swears = ['putang_ina_freq']
swears.extend([x + '_freq' for x in words])
df_all[swears].T.sort_values('all', ascending=False)
# Out:
#                   all
# putang_ina_freq  1829
# gago_freq         597
# yawa_freq         536
# tangina_freq      427
# puta_freq         426
# shit_freq         256
# fuck_freq         175
# bitch_freq        168
# bullshit_freq      86
# dick_freq          56

# %% [markdown]
# >So these are his top swear words. Let's plot it.

# %%
# plt.figure(figsize=(15,8))
words = ['putangina', 'puta', 'tangina', 'gago', 'yawa', 'fuck', 'shit', 'bitch', 'dick', 'bullshit']
keys = ['putang_ina_freq',
 'puta_freq',
 'tangina_freq',
 'gago_freq',
 'yawa_freq',
 'fuck_freq',
 'shit_freq',
 'bitch_freq',
 'dick_freq',
 'bullshit_freq']

counts = [df_all[x].values[0] for x in keys]
plt.figure(figsize=(8, 5))
plt.bar(range(len(words)), counts, alpha=0.5)
# plt.barh(counts, range(len(words)), counts, alpha=0.5)

plt.xticks(range(len(words)), [x.upper() for x in words ], rotation=20)
show_number(counts=counts, y_offset=20, x_offset=-0.09, fontdict={'fontsize':10})
plt.title('PRRD favorite swear words', size=15)
sns.despine()
plt.ylim(0, 1750)
# plt.text(0, 350, 'Keep in mind that these are just the number of occurences of \nthese words he could be referring \
# to another person/animal.')
plt.text(2, 1250, 'The good old yawa, now we\'re talking. Mao rana ser?')
# plt.savefig('pictures\\Num_Top_Donors.png')
plt.show()

# %%
# plt.figure(figsize=(15,8))
words = ['putangina', 'puta', 'tangina', 'gago', 'yawa', 'fuck', 'shit', 'bitch', 'dick', 'bullshit']
keys = ['putang_ina_freq',
 'puta_freq',
 'tangina_freq',
 'gago_freq',
 'yawa_freq',
 'fuck_freq',
 'shit_freq',
 'bitch_freq',
 'dick_freq',
 'bullshit_freq']

counts = [df_all[x].values[0] for x in keys]
plt.figure(figsize=(8, 5))
plt.barh(range(len(words)), counts, alpha=0.5)
# plt.barh(counts, range(len(words)), counts, alpha=0.5)

plt.yticks(range(len(words)), [x.upper() for x in words ])
show_number(counts=counts, y_offset=-0.1, x_offset=10, orientation='horizontal', fontdict={'fontsize':10})
plt.title('PRRD favorite swear words', size=15)
sns.despine()
plt.text(counts[4]+ 100, 3.90, f'- mao rani mayor?')
# plt.savefig('pictures\\Num_Top_Donors.png')
plt.show()

# %%
words = ['putangina', 'puta', 'tangina', 'gago', 'yawa', 'fuck', 'shit', 'bitch', 'dick', 'bullshit']
words = [x.upper() for x in words]
keys = ['putang_ina_freq',
 'puta_freq',
 'tangina_freq',
 'gago_freq',
 'yawa_freq',
 'fuck_freq',
 'shit_freq',
 'bitch_freq',
 'dick_freq',
 'bullshit_freq']
counts = [df_all[x].values[0] for x in keys]
swear_dict = {key:count for key, count in zip(words, counts)}
swear_dict
create_word_cloud2(swear_dict)

# %% [markdown]
# # 8. Number of times the word 'Bong' is mentioned <div id='section8'></div>

# %% [markdown]
# ## 8.1 Mentioned Bong Yearly basis <div id='section81'> </div>

# %%
#group records by year

years = [2016, 2017, 2018, 2019, 2020]
freq_lt = []
for year in years:
    freq_lt.append(count_num_occur(df_years.loc[year, 'concat_trans'], 'bong'))
df_years['bong_freq'] = freq_lt
display(df_years)
# Out:
#                                            concat_trans  num_trans  bong_freq
# 2016   president fidel ramos sir salamat tulong maki...        180         67
# 2017   kindly sit salamat secretary delfin lorenzana...        234         77
# 2018   salamat kindly sit agrarian reform secretary ...        195        199
# 2019   kindly sit sorry looking social welfare devel...        131        355
# 2020   bong mayorship days moment bong right nasabi ...         51         66

# %% [markdown]
# >So these are the number of occurence of the word "bong" starting from 2016 to 2020. We'll plot them

# %%
#PLOTTING - we'll do a bar graph
plt.figure(figsize=(5, 6))

years = [2016, 2017, 2018, 2019, 2020]
plt.bar(range(len(years)), df_years.bong_freq, color='blue', alpha=0.5)
plt.xticks(range(len(years)), years)
plt.ylim(0, 400)
#TEXT
show_number(counts=df_years.bong_freq, y_offset=-13, x_offset=-0.2, fontdict={'fontsize':13}, color='white',round_off=True)
plt.text(-0.5, 380, "Number times DU30 ", fontdict={'fontsize':14})
plt.text(-0.5, 360, "mentioned the word ", fontdict={'fontsize':14})
rainbow_text(-0.5, 338, strings=['"', "Bong", '"', ' yearly basis.'], 
             colors=['black', 'green', 'black', 'black'], size=[17, 17, 17, 14])
# plt.text(-0.5, 318, "years. ", fontdict={'fontsize':14})

sns.despine()
plt.savefig('pictures\\Num_Bong_Years.png')
plt.show()

# %% [markdown]
# ## 8.2 Mentioned Bong Monthly basis <div id='secion82'> </div>

# %%
freq_bong_month_lt = []
for trans in df_months.concat_trans.values:
    freq_bong_month_lt.append(count_num_occur(trans, 'bong'))
    

df_months['bong_freq'] = freq_bong_month_lt
display(df_months)
# Out:
#            date_str                                       concat_trans  \
# 2016 6   2016, Jun.   president fidel ramos sir salamat tulong maki...
#      7   2016, Jul.   let begin addressing officer brigadier genera...
#      8   2016, Aug.   intend interrupt ganito discourteous walk lot...
#      9   2016, Sep.   maayong hapon  let begin work id like remind ...
#      10  2016, Oct.   salamat kindly sit secretary judy taguiwalo; ...
#      11  2016, Nov.   wanted structures government destroyed occupi...
#      12  2016, Dec.   busy day midsayap pumutok simbahan day magbiy...
# 2017 1   2017, Jan.   kindly sit salamat secretary delfin lorenzana...
#      2   2017, Feb.   dureza naka raise konting pera akala ma relea...
#      3   2017, Mar.    salamat sit excellencies diplomatic corps pa...
#      4   2017, Apr.    excellency president joko widodo madame iria...
#      5    2017, May    kindly sit thank secretary delfin lorenzana;...
#      6   2017, Jun.     im glad tonight  enemy contend resistance f...
#      7   2017, Jul.   kindly sit thank courtesy read prepared speec...
#      8   2017, Aug.   pages need longer time start rattling cabinet...
#      9   2017, Sep.   kindly sit thank courtesy came hundreds miles...
#      10  2017, Oct.   prime minister abe committed flesh japans spe...
#      11  2017, Nov.   nandoon medyo matagalan amoy bagoong boodle s...
# 2018 1   2018, Jan.   kindly sit assalamualaikum maraming salamat p...
#      2   2018, Feb.   time maybe alongside mass surrenders ferocity...
#      3   2018, Mar.   thank courtesy kindly sit prepared speech pag...
#      4   2018, Apr.   clear relations larger community nations asea...
#      5    2018, May   salamat kindly sit pages mul billion investme...
#      6   2018, Jun.   maraming salamat kindly standing sit sitting ...
#      7   2018, Jul.   salamat courtesy kindly sit good written spee...
#      8   2018, Aug.   daghang salamat  kindly sit thank courtesy pr...
#      9   2018, Sep.   commander tikas pahinga order requested thank...
#      10  2018, Oct.   kindly sit salamat kortesiya naa koy pages sp...
#      11  2018, Nov.   kauban gobyerno bobby; asawa; opisyales diri ...
#      12  2018, Dec.   salamat kindly sit agrarian reform secretary ...
# 2019 1   2019, Jan.   magandang hapon sinadya pupunta maynila diver...
#      2   2019, Feb.   salamat kindly sit thank id like talk penchan...
#      3   2019, Mar.   kindly sit thank excellencies diplomatic corp...
#      4   2019, Apr.   nandito sigurado education secretary leonor b...
#      5    2019, May   nikkei president naotoshi okada excellencies ...
#      6   2019, Jun.   salamat kindly seats page prepared speech bab...
#      7   2019, Jul.   kindly sit magandang hapon magandang gabi pal...
#      8   2019, Aug.   ndyour excellency pleased undertake visit cor...
#      9   2019, Sep.   xiè xie kindly sit trade industry secretary r...
#      10  2019, Oct.     start question   yes   taking bangkok tomor...
#      11  2019, Nov.   salamat magsiupo sit think time grace occasio...
#      12  2019, Dec.   kindly sit sorry looking social welfare devel...
# 2020 1   2020, Jan.   sit salamat house speaker alan peter cayetano...
#      2   2020, Feb.   kindly sit salamat late pasig maka lantsa com...
#      3   2020, Mar.   ikatlong linggo pakigbisog formidable enemy s...
#      4   2020, Apr.   ahead yes berna good evening countrymen nagpa...
#      5    2020, May   bong mayorship days moment bong right nasabi ...
#      6   2020, Jun.     let start discussing issues affecting healt...
#
#          num_trans  bong_freq
# 2016 6           1          0
#      7          21          3
#      8          29          2
#      9          35         19
#      10         30          8
#      11         22          4
#      12         42         31
# 2017 1          19          7
#      2          21          0
#      3          32         21
#      4          32         11
#      5          25         14
#      6          24         10
#      7          18          2
#      8          18          6
#      9          23          5
#      10          5          0
#      11         17          1
# 2018 1           9          5
#      2          19         33
#      3          16         12
#      4          23         11
#      5          23          5
#      6          19         23
#      7          12         17
#      8          14         10
#      9          19         16
#      10         13         34
#      11         15         18
#      12         13         15
# 2019 1           9         30
#      2          13         30
#      3          14         51
#      4          13         71
#      5           9         55
#      6          12         32
#      7          13         25
#      8          11         20
#      9           9         14
#      10         10          4
#      11          7          8
#      12         11         15
# 2020 1          14         24
#      2           9         11
#      3          10         11
#      4          10          7
#      5           7         10
#      6           1          3

# %% [markdown]
# >So these are number of times DU30 mentioned the word 'bong'. As you can see there are missing months, as they are not available in the website. Let's graph this.

# %%
plt.figure(figsize=(15, 10))
plt.bar(range(df_months.shape[0]), df_months.bong_freq, alpha=0.5)
plt.ylabel('Count', fontdict={'fontsize':12})
plt.xlabel('Date', fontdict={'fontsize':12}, labelpad=30)
lbl = [x[6:].strip() for x in df_months.date_str.tolist()]

plt.xticks(range(df_months.shape[0]), lbl, rotation=90)

txt = ['Number of times Duterte utter the word', '"', 'Bong', '"']
colors = ['black', 'black2', 'green', 'black2']
sizes, colors = get_size_color(colors=colors, size_black=20, size_others=23)
rainbow_text(2 ,73, strings=txt, colors=colors, size=sizes)
plt.text(2, 70, 'monthly basis.',fontdict={'fontsize': 20})


freq_april_2019 = int(df_months.loc[(2019, 4), 'bong_freq'])
average = df_months.bong_freq.mean()

#text rendering
txt = ['On average he utter the word', f'{int(average)} times/month', '.']
colors = ['black', 'red', 'black']
sizes, colors = get_size_color(colors=colors, size_black = 15, size_others=15)
rainbow_text(2, 60, strings=txt, colors=colors,size=sizes)
plt.text(2, 55,f'On April of 2019 just before Senate election he mentioned \n"Bong" {freq_april_2019} times.', 
         fontdict={'fontsize':15, 'color':'blue', 'alpha':0.8})
plt.text(9.5, 55,'The most frequent in all months.', fontdict={'fontsize':15})
plt.text(2, 52.5, 'This is expected as this was during the (PDP-Laban) Campaign Rally.', fontdict={'fontsize':15})
plt.text(2, 48, '(sana ol)', fontdict={'fontsize':15, 'color':'grey', 'alpha':0.3})
total = 0
for i in df_years.index.values:
    val = df_years.loc[i, 'num_months']
    total += val
    offset = (total / df_months.shape[0]) - 0.01
    line = plt.Line2D([offset,offset], [-0.1, 0], transform=plt.gca().transAxes, color='black')
    line.set_clip_on(False)
    plt.gca().add_line(line)
    plt.text(total - (val * 0.5), -6, i,  horizontalalignment='center', verticalalignment='center',
                clip_on=False)
    
#average
plt.text(0.1, 16, 'Average', color='red')
plt.plot(range(df_months.shape[0]), np.full((df_months.shape[0]), 15), color='red', alpha=0.5, linestyle='--')
# plt.axhline(average, color='red', alpha=0.5)

#arrow
xy_largest = (df_months.index.tolist().index((2019, 4)) + 1, 70)
plt.annotate('', xy=xy_largest, xytext=(xy_largest[0]+6, 69),
            arrowprops=dict(facecolor='blue', shrink=0.05, alpha=0.6), )
plt.text(40, 68.5, 'April 2019', fontdict={'fontsize':13, 'color':'blue', 'alpha':0.8})
plt.xlim(0, df_months.shape[0])
sns.despine()
# plt.savefig('pictures\\Num_Bong_Month.png')
plt.show()

# %% [markdown]
# # SAVE - NEVER FUCKING RUN THIS

# %%
with open('pickles\\df_all.pkl', 'wb') as fl:
    pkl.dump(df_all, fl)
    
with open('pickles\\df_months.pkl', 'wb') as fl:
    pkl.dump(df_months, fl)
        
with open('pickles\\df_years.pkl', 'wb') as fl:
    pkl.dump(df_years, fl)
    
with open('pickles\\df_countries.pkl', 'wb') as fl:
    pkl.dump(df_countries, fl)

with open('pickles\\df_nationality.pkl', 'wb') as fl:
    pkl.dump(df_nationality, fl)
    
with open('pickles\\df.pkl', 'wb') as fl:
    pkl.dump(df, fl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-74908c8d50f3> in <module>
#       1 with open('pickles\\df_all.pkl', 'wb') as fl:
# ----> 2     pkl.dump(df_all, fl)
#       3
#       4 with open('pickles\\df_months.pkl', 'wb') as fl:
#       5     pkl.dump(df_months, fl)
#
# NameError: name 'df_all' is not defined

# %% [markdown]
# # LOAD

# %%
# with open('pickles\\df_all.pkl', 'rb') as fl:
#     df_all = pkl.load(fl)
    
with open('pickles\\df_months.pkl', 'rb') as fl:
    df_months = pkl.load(fl)
    
with open('pickles\\df_years.pkl', 'rb') as fl:
    df_years = pkl.load(fl)
    
with open('pickles\\df_countries.pkl', 'rb') as fl:
    df_countries = pkl.load(fl)
    
with open('pickles\\df_nationality.pkl', 'rb') as fl:
    df_nationality = pkl.load(fl)

# %% [markdown]
# # Discovery

# %%
df_nationality = pd.read_csv('Other Data\\countries.csv')

# %%
df_nationality
# Out:
#     CCA2                  Name CCA3         Nationality
# 0     AD               Andorra  AND            Andorran
# 1     AE  United Arab Emirates  ARE             Emirati
# 2     AF           Afghanistan  AFG              Afghan
# 3     AG   Antigua and Barbuda  ATG  Antiguan, Barbudan
# 4     AI              Anguilla  AIA          Anguillian
# ..   ...                   ...  ...                 ...
# 256   YE                 Yemen  YEM              Yemeni
# 257   YT               Mayotte  MYT              French
# 258   ZA          South Africa  ZAF       South African
# 259   ZM                Zambia  ZMB             Zambian
# 260   ZW              Zimbabwe  ZWE          Zimbabwean
#
# [261 rows x 4 columns]

# %%
df_countries
# Out:
#                   Name Code         name_lower  count
# 0          Afghanistan   AF        afghanistan     10
# 1        Åland Islands   AX      åland islands      0
# 2              Albania   AL            albania      0
# 3              Algeria   DZ            algeria      0
# 4       American Samoa   AS     american samoa      0
# ..                 ...  ...                ...    ...
# 244  Wallis and Futuna   WF  wallis and futuna      0
# 245     Western Sahara   EH     western sahara      0
# 246              Yemen   YE              yemen      3
# 247             Zambia   ZM             zambia      1
# 248           Zimbabwe   ZW           zimbabwe      0
#
# [249 rows x 4 columns]

# %%
all_txt[2492:2492+4000]
# Out:
# 'p***** i** gustong tumulong umaabot   sige papunta ayan bong papuntahin dalhin produkto tawagin ibigay inter agency task force let ask crucial question want satisfied sinasabi mas mura asawang spouses dealers iyang nabili mahal price difference haka haka nagpabili manufacturing company okay anybody anybody like  yes secretary roque sige act accordingly course  maybe wed able statement public latest days nakatambak papel opisina presented public black white corresponding explanations nbi study matter carefully p***** i**** negosyanteng issue humanity greed hoarding business practices obnoxious repulsive human mind start think lets look legally sans maybe suspicion  easy charge person believe  nbi probable cause ahead believe accrues accruing government people working presumption regularity performance duties theres problem coming issue ofws coming pagka tayong 24000 stranded manila stranded sense allowed home local governments accepting accepting mayroong pronouncement policy accept returning ofws masama ganun behavior secretary bello says 302 coming short 62000 302 62000 expected arrive soon airports open confusion desire protect respective turf territories ganun say way handle like somebody chieftain city province pandemic time okay nagkasakit cruel actually deny home nandito hotel home lack money resources instructed secretary roque ordering use government assets air sea transportation owned government utilized accepting probably delivering possible delivering homes families coming 302 big worry 62 dadating shortly tinanggap magkagulo pilipinas let clear let talk legality tayong tayong sakit loob stifle right traveling working outside coming going home temporary aberration movement people covid sasabihin said national government impose restrictions travels agency declare emergency national issue national power declaration shared anybody national government siyudad ayaw tanggapin im ordering accept open gates territories allow people allow filipino travel want sequestration tao lockdown dovetail national policy better confuse people allowed unilaterally declare ganito closing entry egress ingress tao mahirap magkagulo kayong want measure implemented local government unit ask permission task force involves issues humanity constitutional right pinakamabigat constitutional right people home travel home impede obstruct movement people run risk getting sued criminally iyang agency national government declared national emergency involving pandemic issue health power shared anybody want adjunct government maghingi permiso task force better position assess kawawa 24 ordering kasali pera naiwan 200 million gastusin uwi tao reason connected issue covid nagsi uwian dineport pandemic involving entire planet earth reason deported forced home maybe contagion involving lot numbers contain kababayan pinapauwi tanggapin kindly sit  defense secretary delfin lorenzana; interior local government secretary eduardo año; senator bong go; afp chief staff general filemon santos sir; philippine national police chief general francisco gamboa sir; philippine military academy alumni association incorporated chairman edgar aglipay sir; philippine national police academy alumni association incorporated chairman william macavinta sir; philippine military academy masidlawin class 2020; philippine national police academy mandayug class 2020 period live vineyard comfort troubled times dangerous abnormal times caused fast spreading highly contagious virulent virus covid 19 cuts humankind aspect human life affected terrible curse lurks corner turn space people meet converge people human activity economic financial wise affected sadly end appears months months away meantime measures alleviate mitigate hardship wrought raise hopes sooner later cure set free covid 19 shall available patience perseverance resiliency crying needs moment trust filipino person virtues abundant said let extend warmest congratulations best wishes graduating day salute napakahusay hurdli ...

# %%
txt = 'tfdf tae'
txt.find('ff')
# Out:
# -1

# %%
putang_lt = find_occur(all_txt, 'p*****', num=200)

# %%
america_lt = find_occur(all_txt, 'america', num=200)
america_lt
# Out:
# ['america think 2000 mahirap buti ganito ha baka napakahusay duterte lockdown  niyan doktor social dis',
#  'america ganito problema america problem filipinos karaming tinamaan patay maski nananawagan basta nu',
#  'america died noong araw 1000 yesterday 2000 today yesterday araw araw nangangailangan nurse express ',
#  'america sense eat buy products sorts pagka meron fda approved theres mark fda galing amerika kampant',
#  'america bumaba patay prediction dire long vaccine medicine men science think end suffer kailan sabih',
#  'america thousands pinipili ayaw ninyong maniwala lumabas ganito nahuli pulis ganito sinita pulis ina',
#  'america im sure meron share rest world meantime naghihintay hong problema pumuputok hirap trabaho ne',
#  'american practice labas pasakay palaboy laboy kang sisigaw sigaw lalapitan pulis military tatanungin',
#  'america japan working overtime come vaccine takes time mundo gobyerno especially rich technology uma',
#  'america practicing fellow human asawa magtrabaho maliit sweldo lokohan tapos gabi gabi ginagamit amo',
#  'americans ipalagay totoo trabaho kagaya pogo assure oath office president republic elected pogo inso',
#  'america survive nation need america fight rebellion entire country need arms hawak hawak rebelde nin',
#  'americans province china ganun insurrection amerika flip magsabi knee jerk reaction deliberate thats',
#  'america americans good imbento pilipino ninakaw totoo niyan stop slowly edge corner assisting ambula',
#  'americans graduate magpunta america training things did chinese fighting communists 53 years nakatul',
#  'america labas gabi p*** punta la south washington pulis magsabi meron niyan p*** puntahan ganon dava',
#  'american help p***** i** namamatay pulis sundalo everyday americans kapalit niyan visiting forces ag',
#  'america hit arms accounting nuclear arms inside philippines brought americans weeks ago reading news',
#  'america thats im warning time correction terminate bases visiting forces agreement tapusin p***** i*',
#  'american government month istorya mi pahawaon nako ilang visiting forces agreement second kadtong se',
#  'america aral sus make finish line imponderables life mamatay mahulog mabangungot mabaril girlfriend ',
#  'america retire bumalik kayong problema legal problem saka kayong matakot pera galit comms said wrong',
#  'america excuse pretext weapons mass destruction pinatay saddam weapons mass destruction sundalo tuma',
#  'america kawawa mayaman maganda surplus pera putulin graft corruption putulin droga putulin sumisira ',
#  'americans reason actually recruit natives muslims moro actually tawag moros moro mapa trabaho time n',
#  'americans said mindanao land promise actually p** silang trabahante ayaw moro import sloganeering we',
#  'america separated medyo mahirap climate change thing present inutile commission does sanctions commi',
#  'americans demand stand rights pilipino natatakot approaches window bir permits local level clearance',
#  'america lusot ganito manigarilyo vaping nanigarilyo labas bawal manigarilyo batas hinahabol nicotine',
#  'americans operated country drugs cocaine meth recorded events led murder lee buffeted destroy countr',
#  'america swallowing pinaka amerikano baba malakas narco politics come pass mayors loot ngayong im wai',
#  'america makahawak quota quota siyang export malakas sugar patay sugar makukuha makukuha corn makukuh',
#  'america leaves nang pagkukunan ari sugar mills plantation blame government free market member wto la',
#  'america ma hold pilipinas sugar quota sugar quota racket mayaman kayong haciendero bagong modelo mer',
#  'america aral time nung mahal sugar humahawak ika bibliya time wallowing money makibagay aint rich an',
#  'america conference dea drug enforcement agency told rate dru drugs drowning country narco state time',
#  'americans allow foreign power maski america britain allow deployment nuclear arms talagang pupuntaha',
#  'america deprived lands americans nung amerikano magpunta magtrabaho plantasyon hired visayans approx',
#  'america sige tingnan america nalango barilin mcdonalds barilin simbahan pouring mahirap maghanap hon',
#  'america nagsibatan anak sinabi davao paint corner ayaw ayaw inipit gobyerno tao gobyerno makagalaw u',
#  'america tapos december 21 sumunod maam 22 naiba istorya nanay tatay bring months bumalik law pilipin',
#  'america mao import silag sugar places sugar planted industry mao nahitabo karon gibaligya gikuha nil',
#  'americans mindanao especially homestead 24 hectares given corporations hard crack areas feudalism al',
#  'america stanford ata bright 75 p***** i** tsk nung presidente tinitignan tugade tugade valedictorian',
#  'american period pc chief pc served chief law enforcement predecessor current police organization phi',
#  'americans created reason china went make friends kasama bingbong secretary lopez military año lorenz',
#  'americans day naghingi bayad utang loob toothpick magdududa military alliances entered agreement chi',
#  'america violation constitution meron 1951 think tama namang treaty treaty dont need treaty solemn pr',
#  'america paliparin missile cross philippines make sure does fall short magagalit makipag away geopoli',
#  'america magpunta amerikano china useless military alliances war china release missiles nuclear ameri',
#  'americans binitawan nabitawan china australia kaming isali thats want anybody magka giyera americans',
#  'america talagang bawal pinigilan nandiyan ready fight death tinutulak p***** i** carpio company papa',
#  'america invited trump tapos congressman senador nagtindig pupunta totoo kayong makausap 8888 ptv 4 a',
#  'america baka nakikinig honeylet  classmate anak  pinangalanan anak girlie p***** i** binatukan honey',
#  'america parlade attorney parlade anak girlie nanay honeylet nandiyan p*** sapak p***** i** sunod ele',
#  'america rest parang unggoy hear talk time alunan ramos president called dea america told rate drug p',
#  'americans tawagin tayong copycat whats wrong copying good practices good governance tell people asse',
#  'americans came wanted exploit cultivate mindanao theres typhoon plant grows come think  youd notice ',
#  'america took years europe problem philippines beset said runaway population 110 108 say rely availab',
#  'americans time republic created somebody men try cory aquino ganito cory aquino popular popular toda',
#  'america gave philippines premium price sugar sugar quota pinagbibili pinag agawan kagaya nitong lott',
#  'americans wanted develop awardan 100000 want example walstrom kilometers thats 1000 1000 hectares ow',
#  'americans try wipe filipino government local governments allow tit tat thats order military deserve ',
#  'america especially europe magyabang puti day run human pinakagwapo pilipino pilipina nonproductive p',
#  'america care brewing did did seek peaceful means arbitral tribunal lost nandoon talk reality talk co',
#  'america china philippines indonesia matter historically tao tao nakatira small number occupied human',
#  'americans meron nang nakatira ditong pilipino siguro tawag pilipino ganyan china china claim ownersh',
#  'america sige parking seventh fleet iparking navy ginagamit bangka jolo tapos p***** mmm tingnan ganu',
#  'americans homeland mindanao talagang nawatak watak coming droves ilocano bisaya tagalog everybody mi',
#  'america prodding congress quandary reports ripe passing arms marawi arms hands police hands army qui',
#  'america rate drug suffocating country wishful thinking narco state short time time far wide years va',
#  'america ayaw despite overflights tapos pakunwari planet past seven years ago newspapers abrewing spr',
#  'america seventh fleet pinuntahan spratly say hinayaan medyo nandiyan guns missiles mounted want enfo',
#  'america earlier did surprised wants tickle china pumutok masakripisyo papasabugin palawan nandiyan f',
#  'america pushing egging tinitikoy bait anong tingin pilipino wati  dalhin eroplano barko china shot n',
#  'america u rp pact okay let america declare war let assemble armaments south china sea shot ill glad ',
#  'america happen philippines asia thats geopolitics laro g*** mabutit mahirap siguro presidente nabigy',
#  'americans id like thank heart work want stay philippines said considering invested im rich 15 billio',
#  'america napunta ganon patience criminal ive prosecutor years doing trial work saw agony guilty perso',
#  'america china armas pinaglaki agriculture ayaw makipag away argument dumating china great power arse',
#  'america said geopolitics western power overflights padaan daan confront china directly istambay ari ',
#  'america power time stop lifted finger totoo nandito allowed military base time supposed america youd',
#  'america did papasok sail ganun maintindihan inallow started simple housing beach runway tapos bawal ',
#  'america magpadala barko china claim island pinakamahaba 12 miles coastal high low tide low tide high',
#  'america 63000 m16s sig sauer binara amerikano dont needed firearms firearms loose bore tumatalsik bo',
#  'america ayaw ngang confront tapos ipusta mapasubo dalhin giyera talagang giyera pinuntahan alang ala',
#  'america britain france assemble palawan tapos diretso spratly agawin maagaw maubos youre g****** s**',
#  'americans popular notion ayaw central government created spaniards passed americans present governme',
#  'america right interfere bloody confrontation thing invocation rp concurred congress america war pres',
#  'america claiming pacific ocean pagpasok galing palawan galing india papunta celebes mindanao pacific',
#  'america claim pacific australian claim danger talk lengthily asean matter 10 dash dash  simple claim',
#  'americans fought foreign domination lapu lapu continued unrecognized president created order lapu la',
#  'america drug enforcement agency told point blank country improve present situation combatting drugs ',
#  'america canada dont kill violent criminals citizens cutting heads foreigners filipinos everybody gro',
#  'america im saying like trump like assure america hinder hamper alliances china russia enemies dineli',
#  'americans asking base say reach time faster dont need bases submarines right pantalan kaibigan ameri',
#  'americans look nation inferiors especially colonized subjugated 50 years think inferior castigate pr',
#  'america afford pay 30000 month 100000 kinolekta pasok problema like legacy end day makuha syndicated',
#  'america helpful purchase arms bad experience new policy going  buy think need kind particular id lik',
#  'americans officials washington deprived arms started going scouting cheaper better arms contracts me',
#  'america war america china war useless thing arsenal tapos mundo say blow 100 times bigger hiroshima ',
#  'america russia puputok china puputok south korea puputok north korea arms iran arms france arms ital',
#  'american set foot asa island create trouble allow arms philippine government arms given america that',
#  'americans claimed philippines subject cruel foreign domination prick mind react certain acts western',
#  'america signed treaty china got dont think russia happy membership ails conference climate change ta',
#  'america testing waters testing waters temperature god testing shot sad bewildered angry hope china c',
#  'america china talking surety territories end shouting match china standing partner china sea republi',
#  'america asawa dati malaman nanay inday pulong sebastian unfortunately sadly magka intindihan kayong ',
#  'america shes half german half american parang iniwan malaman kasalanan ayaw problema told reason lea',
#  'america garage converted garage converted room tapos pinaparenta tu natulog nirerentahan totoo kot m',
#  'america think 40 percent 35 percent salary goes government trabaho gobyerno maiwan work government g',
#  'america japan aaa bbb+ course marating budget officer promoted central bank managership ben diokno m',
#  'america everyday droga artista tingnan youtube pumasok akalain tingnan youtube ar kita bata tapos st',
#  'america america sustain ayaw gulo iwanan japan korea china okay amerikano napunta china order puputo',
#  'america china kasalanan nagbili  fault anybody help japan truly good faith sweat unang theyre kind p',
#  'americas markets preferential tariff arrangements philippines manufacturing philippines ideal base h',
#  'america ron daghang cardinal nahawa past sins kanus namakak dili baba manila mobuga kog bastos tinuo',
#  'america dili bloody moatras mao nay sabot p***** i** niatras ta g***** del rosario wa pugsa china ka',
#  'america infiltrate federal government liza modaog  ayuha pagdala gobyerno ha bonifacio militar kani ',
#  'america took doctor judicial science studies tulane law school new orleans louisiana usa environment',
#  'america warned narco state coming shores parojinog p***** i** espinosa ganun bisyo drop magawa respo',
#  'americans mindanao islam spaniards came muskets cannon gunpowder natives kneel sheer firepower ameri',
#  'americans started divide nation mindanao opened introduced torrens title; like america distribute la',
#  'american version giving away public lands big problem forgot came adam eve im referring tribes moro ',
#  'america alunan secretary dilg marcos time told subsequent presidents youre gonna read buy bust opera',
#  'america official trip things did talk dea officials drug enforcement agency america time marcos sina',
#  'america bright tao master laws university london anak honors doctorate doctor judicial science studi',
#  'america suicide america nuclear war basig pagka nuclear war ubos tayong mundong russia bitawan bitaw',
#  'america risk world war defend makuha spratly spratly iyang scarborough scarborough nawala aquino sta',
#  'america nagpaareglo gulo withdraw pumayag dalawang withdraw china umalis nangyari research time aqui',
#  'america sinabihan tinawag mayors tanungin mayor tinawag malacañan anong sinabi f*** drugs kill sinab',
#  'america talked dea maoy sulti giignan drug enforcement agency federal government ramos ha pak rate c',
#  'america tan awa og unsay sala naa diha kanang madre dugay mao sabton bakakon usa presidente nganong ',
#  'america bar exam reciprocity reciprocal pwede pwede nakapasa bar exams master laws university london',
#  'americans time needed went russia china gave libre ibinigay id like address filipino people day toot',
#  'americans suspended 23000 rifles ordered marawi brewing nagpapasa armas shooters bore marcos police ',
#  'americano gumagawa plays piano gitara teng teng teng teng tapos maggawa tune tune maglagay lyrics ta',
#  'americano f**** nandiyan kanta pakinggan mensahe message everybody anak magdalena pipi bingi social ',
#  'america told dea drug enforcement agency sinabi ramos ha dilg tinawag kaming mayors sinabihin daw de',
#  'americans asylum naglaki tapos time long bumalik dala dala american passport nagka l**** dual citize',
#  'america house factory magbili eroplano barko trabaho quality life good national wealth mataas dollar',
#  'americans went gave choices lands elite hate rich people sure heard talking elite abusing country ta',
#  'america like mabilog iloilo asawa sige yawyaw tignan nagpunta iloilo kita pinaka luod bisaya pinaka ',
#  'america failed deliver ordered luma armas marcos barrel maluwang lalabasan bala trajectory lumalabas',
#  'americans problema kayong mabigat droga naagapan ewan naagapan barangay captains nasa listahan mayor',
#  'america usa ra stretch border ato pila pud island og imo nang tugpong tugpongon malibot nato kalibut',
#  'america puro gyud basta naay pari olden times pope leo iyang gikabit iyang kaugalingong anak produce',
#  'america america hes america im sorry maybe canada siegfredo betita mayor carles iloilo; mariano m ma',
#  'america 23000 bigla nagsabi america congressman senador took floor denounce human rights violation d',
#  'americans active intelligence situation ayaw ibigay went sent word china want visit xi jinping went ',
#  'america contribute make hard philippines population 110 million anak 110 million contamination 20 25',
#  'america talk behalf president nangyari galit galit china problema armas sundalo luma americans count',
#  'american congressman senator stood floors congress dinenounce send gobyerno use citizen maintindihan',
#  'americans spaniards revolution phi mindanao things think dedicate solving pwede able bangsamoro law ',
#  'american occupied country 50 years lived fat land nagkaganito say mindanao land promise truth mindan',
#  'americans invented existing torrens title actually american origin homestead divided mindanao centur',
#  'america punta especially europe punta simbahan sarado im sure nagpupunta america tignan simbahan sin',
#  'america aint way make headway make npas irrelevant buhay pilipino bang silbi sige hingi sige patay b',
#  'america nandoon sinabi rate country converted shabu amerikano narco narcopolitic state sinabihan ram',
#  'america stretch dalawang submarino ganunan island island afford patrol island island ganun kahirap i',
#  'america nay kwarta gisulti law order corruption maintenance nalang ta og way swerte karon niadto kog',
#  'america sabiko nung b******** obama kasialammosi obama attacking press conference sabiko presidente ',
#  'america sailing dark horizon dark state narcopolitics knew declaring war declaring punitive police a',
#  'americans understand workings democracy document noun pronouns verbs adjectives american society fil',
#  'american society coming think week talk relations friendship time head state im referring previous p',
#  'america criticize attack condone state department doing think early time president ramos alunan secr',
#  'americans stayed 50 years live fat land thats good reason youll lecturing morality righteousness ind',
#  'america far east gave indonesia brunei malaysia god gave maybe die ask lord happy im doing instead m',
#  'america trillanes issue hong celebrate birthday wife order daughter order daughter like order mayor ',
#  'americans 50 years lived fat land kinuha magagandang anong maganda bayan moro ayaw magtrabaho amo di',
#  'american given 1027 hectares pinakamalaki davao banana plantation danding cojuangco want offend anyb',
#  'americans europeans dont whats whats table whats whats card table tapos pahirapan pilipino madali ma',
#  'america buhay obey rules period maski sundin batas tayong problema everybody money suweldo sundin ba',
#  'american titling land problema sumusunod ideolohiya nur misuari murad sinusunod isis isis napanganak',
#  'america human rights magsabi p***** i** pagdating sumabog bayan easy lose country disintegrate time ',
#  'american sloganeering mindanao land promise totoo niyan muslim trabaho mayayaman kastila amerikanong',
#  'americans davao mindanao land promise actually told truth time mindanao subdivided homesteads grants',
#  'americans came got concessions owning thousands hectares lands davao developed big maliit pagdating ',
#  'americans pamilya original amerikano germans granted asylum quezon nagpuntahan mindanao inday theres',
#  'americans 50 years dont say did die sins people filipinos malay blood sana left problem possible lim',
#  'americans came estudyante ninuno sinasabi problema force kill needlessly want hope addressed beloved',
#  'america land reform bat kinokopya kinokopya nandiyan galing puso migrants mindanao mama mindanaoan t',
#  'americans puro kristiyanos original taga mindanao kristiyanos thing time magellan landed leyte 1521 ',
#  'americans time sheer population increase numbers civilization meron tayong problema make concessions',
#  'america napagkasunduan chief police kayong maniwala human rights inutil p****** i** mang utak slight',
#  'america nasudlan og left began accommodating komunista ngadto america ila bang gipamutangan og pwest',
#  'america philippines long tedious process point outcome disappointing long wait rest filipino nation ',
#  'americans bells returned credit goes american people filipino people period behalf nation thank stak',
#  'america daghang salamat kaninyong tanan daghang salamat filipino mabuhay pilipinas source pcoo pnd k',
#  'american periods ibinigay homestead thats american invention thats homestead america patterned distr',
#  'american government local executives local executives turn rightful owner people balangiga pari want',
#  'america medyo barkada delfin matagal cia america veterans totoo puro cia alan cayetano cia mura pud ',
#  'america citizen turned thats problem kasama dormitory akalain years magkita kita workers government ',
#  'america seek sanctuary maceda set law office prospered suffered ipadala stares eyeball eyeball thing',
#  'america keeps binibira iran iran time oil price increases hatakan world oil magtingin tao oil siguro',
#  'america america distant star understand way behave korea help kanang airport nato niadto thats korea',
#  'america started obama trump cleaning mess obama reprimanding press interview kaming head state qualm',
#  'americans did catch fleeing japanese extend vast expanse destruction asya nang konting pera nagtulon',
#  'america bulk money went japan think reason guilt feeling using hydrogen bomb nagasaki hiroshima cour',
#  'americans aid given japan maybe atonement guilt hiroshima nagasaki talagang flattened ginamit atomic']

# %%
len(remove_stop(df_all.concat_trans.values[0]).split(' '))
# Out:
# 1026428

# %%
find_occur(df_all.concat_trans.values[0], 'amerika')
# Out:
# [' amerika sinabi id like address pinapatamaan pilipino countries traditionally lukewarm',
#  ' amerika nagpupuntahan problema amerikano relied human resource umasa sana sariling',
#  ' amerika maraming sumusunod pilipinas bumaba tumaas thousand 4932 4 pm',
#  ' amerika kampante niyan matter fact believe testing ganun pagka assessment',
#  ' amerika trabaho nagbibili eroplano bala gulo manggulo kumikita okay',
#  ' amerika patay italy france day italy day 500 patay deadly',
#  ' amerika wallop maraming patay italy spain france america bumaba',
#  ' amerika ganon lockdown nauna magpasalamat nauna ilang linggo nagdesisyon kaagad',
#  ' amerika preparado hirap russia nagtulong kalaban nagpadala ventilators china preparado',
#  ' amerika ganun akalain buong mundo ganun kabilis dalawang araw receiving',
#  ' amerika mighty power military united states fight rebellion terrorists south',
#  ' amerika flip magsabi knee jerk reaction deliberate thats sleep im',
#  ' amerika nakatingin pulis allowing marijuana',
#  ' amerika look san francisco',
#  ' amerika p***** i** matter weaponry abroad training balikatan balikatan exercises',
#  ' amerika p***** i** ganunin america labas gabi p*** punta la',
#  ' amerika started hukbalahap palaba francisco despite american help p***** i**',
#  ' amerika armas mao nang mangita',
#  ' amerika brought peace tignan iraq syria anak binobomba totoo evolved',
#  ' amerika ibang countries matter australia mahirap mayor tawag mayor mayor',
#  ' amerika bahay matter fact mansion tell medyo ubos ubos kaming',
#  ' amerika congressmen stood congress congress denounce ordering intelligence reports indicated',
#  ' amerika kinausap dea department enforcing alcohol drugs sinabi sinabihan rate',
#  ' amerika gabaligyag eroplanobarko',
#  ' amerika gustog away og wa nay mamalit og eroplano barko',
#  ' amerika trabaho tanan mao awto ngadto halin tanan ngadto hatagan',
#  ' amerika austria nagbili truck bumbero susmaryosep masira yawa magkuha spare',
#  ' amerika away pinu**** i** obama sinabi p***** i**** l**** wag',
#  ' amerika tsaka bossy sarhento tinyente magsalita akala heneral nakikinig listen',
#  ' amerika pabidahan trade imbalance pabor china mas china ganun trump',
#  ' amerika 15000 okay save makuha bong years tagal gikwentuhan kita',
#  ' amerika og giyera kahibaw og magkagiyera unya gamay',
#  ' amerika nahibaw tang tanan og',
#  ' amerika atras mong duha tontong del rosario gipaatras atong barko',
#  ' amerika ug kadyot naa koy usa mensahe wa nako gwapa',
#  ' amerika wa puy gibuhat karon nakumpleto mura kampo gyud naa',
#  ' amerika bilat siyang gani kasulbad ana ilang iran ug iraq',
#  ' amerika mauna mosunod perog akoy mauna hurot sundalog pulis magbilin',
#  ' amerika tama tanungin ilang mayor governor nasangkot droga nandiyan puwesto',
#  ' amerika europe pilipinas p***** i**** bam aquino puro salita puro',
#  ' amerika nakausap dea drug enforcement agency sinabi kaming mayor rate',
#  ' amerika inistop congressional hearing sobra sobra daw baril started disappointment',
#  ' amerika daan tapos nagdaan',
#  ' amerika sinabihan dea drug enforcement agency departamento marcos kita totoo',
#  ' amerika war inaano kaibigan classic example walstrom walstrom resident zamboanga',
#  ' amerika dolyar malaki trabaho nagpapabili barko baril eroplano bala kita',
#  ' amerika español tapos amerikano kunwari binigyan lupa español lolo homestead',
#  ' amerika torrens title american titling land problema sumusunod ideolohiya nur',
#  ' amerika aide annapolis sentimiyento amerikano amerikano military tino state department',
#  ' amerika kita simbahan nagsisimba mexicano pilipino pinakamalaking scandal father falvey',
#  ' amerika raw makagamit armas sibilyan citizens country citizens country trying',
#  ' amerika china pwede magbili baril baril china russia sinabi military',
#  ' amerika tayong problema problema opisyal obama trump kaibigan narinig naghingi',
#  ' amerika abilidad talagang sisikat talent opportunity nating pilipinas limitado theaters',
#  ' amerika icc ikulong ikulong namang problema siguro seriously presidency gift',
#  ' amerika unya mosimba ngadto',
#  ' amerika talagang binibira japan atomic reactors alitan iran hold production',
#  ' amerika china ahead tapos magsabi britain australia sasali russia away',
#  ' amerika drag icc submit idiots icc created europe eu whos',
#  ' amerika itinuturing utang loob understand walay problema ambassador kim naa',
#  ' amerika pinag anong tingin want insult like postal employee mail',
#  ' amerika wilbur ross secretary defense james mattis mike pompeo secretary',
#  ' amerika kagaya pilipinas magtindig senador congressman saka sinabi important owe',
#  ' amerika ayaw submarino bigyan pains imee bang amerikano p***** i**',
#  ' amerika free market idea dumaan pagador appear new maybe engine',
#  ' amerika kulungin buangmga international courtmaniwala kayobolador round tumba nung nilabas',
#  ' amerika behave way katakot exercise right reserved citizens sinasadya god',
#  ' amerika conquered mindanao introduced things island mindanao torrens title place',
#  ' amerika atong kiliran apparently despite spite publication diha karon time',
#  ' amerika graduate studies special training bond bond',
#  ' amerika europe sige buga buga nang maitim reached pinnacle economic',
#  ' amerika nagkabuang buto buto imported terrorism taotingnan communist',
#  ' amerika expertise makisawsaw liit sweldo make salary competitive espesyalista paying',
#  ' amerika nagsimba misis nanay inday humiwalay filed annulment nakipaghiwalay asawa',
#  ' amerika dont id like',
#  ' amerika ibo vote apil apil kog unsa kuwan bat ayaw',
#  ' amerika magpa tuo tuo europe lalo kaning terorista ubuton ilang',
#  ' amerika prankahan ugali',
#  ' amerika knew magnitude problem instead going forward help human rights',
#  ' amerika im going ask sacrifice little bit year entered alliances',
#  ' amerika britain warned iraq dont warning went inside iraq pretext',
#  ' amerika tayong magbolahan treatment foreigners white sige daw kayong aral',
#  ' amerika white people',
#  ' amerika sige turo l**** kang duterte kinakain tapos matakot p*******',
#  ' amerika takutin extra judicial killing demand united states america eu',
#  ' amerika human rights charlotte state emergency daw pinagbabaril itim basta',
#  ' amerika',
#  ' amerika complaining threatening criminals drug syndicates considered fact 37 drug',
#  ' amerika tanungin pinag babarilin itim tapos britain germany warningan arabs',
#  ' amerika hipokrito went iraq flimsy excuse weapons mass destruction killed',
#  ' amerika magsabi duterte sumakay election issue yellow movement yellow alive',
#  ' amerika europe aconvention new york rule non kind weapon lethal',
#  ' amerika pinara kamay nandyan kang magbunot lisensiya babarilin kita amerikano',
#  ' amerika okay totoo e parahin babain tapos iganun human rights',
#  ' amerika ganun nalang happened davao city ditong drug tawag nung',
#  ' amerika thats saying akala binago tong',
#  ' amerika invaded iraq galit muslim e pretext weapons mass destruction',
#  ' amerika ayaw siyang insultuhin ganito ganun refrain election time statement',
#  ' amerika violate okay hoy matagal kaming umalis try lecture governance',
#  ' amerika hipokrito actually problem million plus philippines; million widodo indonesia',
#  ' amerika binanatan sinong bumibira amerikanong rapporteur threatening bringing international court',
#  ' amerika sole allegation weapons mass destruction killed saddam strongman iraq',
#  ' amerika months year shrink brain rehabilitation longer viable supposed crazy',
#  ' amerika problema ganito sama loob occupied country 50 years governance',
#  ' amerika ganito nangyayari namatay mayor iwasan droga sisirain bayan maniwala',
#  ' amerika time criticize goldberg ayaw insulto umpisa away election nakihalo',
#  ' amerika eu progressive countries; kept hammering issue 3000 daw patay',
#  ' amerika sinabi maintindihan wag tayong ma tayong armas dadalawang eroplano',
#  ' amerika damage ke mas bahay building mahal kalsada mas tama',
#  ' amerika magpunta manila sige punta uwian pilipino bagsak',
#  ' amerika maliit historically lalo actually fault president iyang state department',
#  ' amerika nagalit artista daw psychopath leave constitutional right free expression',
#  ' amerika im serving notice iyang style basta utos utos want',
#  ' amerika xi jinping lalo putin kayong talagang wag tayong magkamali',
#  ' amerika basta pusher streets campaign continue cost life honor presidency',
#  ' amerika istorya  namang china im going china make friends',
#  ' amerika ayaw maniwala pressure obey especially america signatory kyoto protocol',
#  ' amerika nagtatakot ipakulong international criminal court signatory body time afraid',
#  ' amerika middle east got votes landslide nagtaas sheer number think',
#  ' amerika aral fundamentally police work tirades america think help appoint',
#  ' amerika tignan nagka utang loob join kailangang coup détat coup',
#  ' amerika ganito mayor subject whipping boy human rights community iyang',
#  ' amerika criticized mayor okay represent entity city big deal presidente',
#  ' amerika wanted control sides atlantic pacific pan pacific partnership things',
#  ' amerika bilib problema nawalaan respeto binabastos binabastos tingnan unggoy 26000',
#  ' amerika makialam im prepared declare war military oh tingin tignan',
#  ' amerika 4 million addicts alipin slaves people sell drugs babalik',
#  ' amerika kinsa pay nakahinumdom – invaded panama usa country',
#  ' amerika dili mexico – panama  gibuhat panama gi invade',
#  ' amerika didto gi huwesan',
#  ' amerika noriega nahidun dum remember noriega gi invade giud unsa',
#  ' amerika karon',
#  ' amerika pud simbahan sige mog panudlo  sige kag tudlo',
#  ' amerika maka solve niyan ganito punta noong mayor sinabi ayaw',
#  ' amerika delikado problema went matter fact kapatid aral daughter america',
#  ' amerika pandagdag gulo buti human rights bang gustong pumatay tao',
#  ' amerika away land hypocrisy 40000 americans killed yea drug connected',
#  ' amerika sindihan yawa asked permission president manny pacquiao  nagbitaw',
#  ' amerika silang maceda got thing talking like everybody b******* ',
#  ' amerika does pay dues nagbabayad buwang totoo',
#  ' amerika nagsabi theres danger talagang totoo kikidnapin tapos lublubin harap',
#  ' amerika im trying say misplace value adopt',
#  ' amerika magandang sundalo pulis maski armed forces ambivalent duterte komunista',
#  ' amerika bato treated like way',
#  ' amerika tapos trump president youre doing right youre okay doing',
#  ' amerika swear swear maski sinong maski ipakilala miss universe tiis',
#  ' amerika aaral war lords protektado mayor barangay captain tapos pulis',
#  ' amerika dont s*** pumili presidente pilipino pilipino poprotektahan  impeachment',
#  ' amerika pretentions hypocrisy makukuha guy said continue youre doing good',
#  ' amerika nagbuhos bilyon flooding america supply cocaine heroine came country',
#  ' amerika killings people president did realize widespread everyday tv people',
#  ' amerika sinabi ganunin p******* i** ninyong tinawagan trump recorded ',
#  ' amerika ipadala daw soldiers brave matter fact die extrajudicial killing',
#  ' amerika g*** pala miyembro tell hypocrisy yes; incongruity yes remember',
#  ' amerika maintindihan obama human rights used criticize mayor president started',
#  ' amerika anak p****** tapos pakialaman 4 million addicts forensics nagsabi',
#  ' amerika said sovereign power think chart enter military alliance country',
#  ' amerika historically animosity owns construction territory territorial establishment kagaya kaharap',
#  ' amerika look want chinese fine ayaw kog',
#  ' amerika amigo nako pasagdan ta ayaw tagdikiti atong saging low',
#  ' amerika jeopardy war anybody option exercised philippines argument entitled like',
#  ' amerika years ago years ago overflights australia countries satellites warned',
#  ' amerika pwedeng kumasa magpunta navy mean massacre soldiers mauna isip',
#  ' amerika nagbi build ayan problema days solved settled did america',
#  ' amerika naluma g***ng amerikano valedictorian hes davao owns marco polo',
#  ' amerika rp pact 1950 51',
#  ' amerika  nakabili aquino idiniliver noong buti maklaro claiming credit',
#  ' amerika pineapple kita sarado 100 percent increase pineapple importation mangga',
#  ' amerika magbigay puro tonka laruan tonka susmaryosep bigyan armas bigyan',
#  ' amerika china nagpapadala navy coast guard palagi coast guard coast',
#  ' amerika hinihintay magulo manggugulo match china kita tv kanina prepared',
#  ' amerika bayad nagpunta tumaba pumayat trabaho brod classmate right',
#  ' amerika look lackey bata bata amerikano eu serve filipino ',
#  ' amerika pinapakialaman trabaho g*** ipakulong mawala scourge bayan pinapakulong buang',
#  ' amerika is****** eu  care young old work sick 85',
#  ' amerika atakihin rp pact honor entered military alliance country create',
#  ' amerika magbigay including theory allowing country pass law allow sex',
#  ' amerika tapos obama chastised public mayor carried brunt criticism said',
#  ' amerika eu played hands opposition pumasok issue campaign issues campaign',
#  ' amerika invaded panama remember reason panama  flooding america drugs',
#  ' amerika sanctuary political prisoners ganun pilipino yasay tayong magawa ganun',
#  ' amerika nagte training pilipinas provide worry meantime sagot ayaw uusapan',
#  ' amerika israel magbili  tapos year tingan sweldo tseke mataas',
#  ' amerika aral consistent scholar valedictorianako nandiyan 10 magbilang 45 klase',
#  ' amerika nagkamali nagkamali akalain bureau customs akala kaalyado faeldon kind',
#  ' amerika china russia nandito kalaban nakikinig nakikinig palagi love ning',
#  ' amerika china russia nandito kalaban nakikinig nakikinig palagi love love',
#  ' amerika naghinto balang araw kita namatay magpakialam patay naghinto ill',
#  ' amerika reprimanding extrajudicial killing dedication memory brothers sisters presidente ive',
#  ' amerika ma utak edukasyon time crank grey matter ears think',
#  ' amerika nakahiga black pagtapos bleeding hearts mas marunong kunwari think',
#  ' amerika congress state department',
#  ' amerika pass scrutiny congress state department way meron silang nauna',
#  ' amerika ecstasy tingnan okay heroin tingnan ha lsd amerikano methamphetamine',
#  ' amerika damay nang',
#  ' amerika remember gold rush state face america west left means',
#  ' amerika maraming magaganda trump invited dalawang senador duterte come participate',
#  ' amerika mao nay kadaghanan ginabuhat ganunin ta gyud undangan threaten',
#  ' amerika chinese',
#  ' amerika anong kept silent did public outcry takot think america',
#  ' amerika maski makapunta bigyan visa young went america question asked',
#  ' amerika ini outsource nike china outsourced assembled theremeron tayong dalawang',
#  ' amerika theres riot going pronounced riot riot theres riot going',
#  ' amerika enforce lockdown sequestration quarantine butit ganun respond problem besetting',
#  ' amerika kamay pulis kamay nandiyan manibelatapos pe permiso padito magsabi',
#  ' amerika tingnan pang heroin travel shabu lulutuin favorite cocaine heroin',
#  ' amerika deposit engaged money laundering bibirahin',
#  ' amerika transmittal forward forward pera  meron matagal  ',
#  ' amerika ganun nasanay anim pito sampung taon 15 20 years',
#  ' amerika mas lalo pilipinas',
#  ' amerika malacañan thatyou rid thing actually loosen bit moro people',
#  ' amerika ganon address congressman napakaarte bumabagay graft corruptionalam magkaibigan magkaibigan',
#  ' amerika nasolve able solve killings thousand deaths 77 step backwards',
#  ' amerika  far different arbitral simply entitlements territorial thing god',
#  ' amerika kuno ahead trial let  maybe yes maybe ',
#  ' amerika bugging civilization  reason hate mexicans  maganda kababayan',
#  ' amerika tried prisoninvading country reasons drugs presidente malaman sinong papatayin',
#  ' amerika umalis akosabi ayaw tapos china come peace want hand',
#  ' amerika malaman values nilaano obama binibira public meron sanang united',
#  ' amerika postal postal customs think fiscal time patawad tong toim',
#  ' amerika magkaibigan ayokong makipag away kakayahan result massacre actually choices',
#  ' amerika niwarningan wag international belongs everybody belongs country binigyan satellites',
#  ' amerika china hey guys supposed international sea owns law putting',
#  ' amerika alipin droga alipin droga masakit  maniwala niyan sige']

# %%
def find_occur(target, key,  num=-1, offset=10):
    if num == -1:
        num = count_num_occur(target, key)
    #check if word is a list or a string
    if type(key) == str:
        key = [key]
    target_lt = target.split(" ")
    lt = []
    count_num_target = 0
    count_num_words = 0
    isSame = False
    
    for i in range(len(target_lt)):
        if target_lt[i] == key[0]:
            isSame= True
            #check if the remaining words are also equal
            for j in range(len(key)):
                if target_lt[j + i] != key[j]:
                    isSame = False
                    break
                    
            if isSame:
                count_num_target += 1
                txt = ''
            if count_num_target == num:
                break
        
        if isSame:
            txt += ' ' + target_lt[i]
            count_num_words += 1
            #once we reached the offset
            if count_num_words == offset:
                isSame = False
                lt.append(txt)
                count_num_words = 0
                txt = ''
        
    return lt

# %%
fuck_lt = find_occur(df_all.concat_trans.values[0], 'f***', num=5)
fuck_lt
# Out:
# [' f*** rules ganun magkakaproblema ospital sanctuary sick choose ailment patient',
#  ' f*** ta hihinto hihinto patay iiwan nandito networks mensahe usap',
#  ' f*** did screwed country ma satisfy expropriate kunin magdemanda nang',
#  ' f*** face pariah international mayaman indonesia malaysia pilipinas parang corpo']

# %%
with open('pickles\\df2_uncleaned2.pkl', 'rb') as fl:
    df_2 = pkl.load(fl)

# %%
df_2
# Out:
#                    date                                              title  \
# 0         June 04, 2020                    Talk to the People. on COVID-19
# 1        April 23, 2020                     Talk to the Nation on COVID-19
# 2        March 24, 2020                                        On COVID-19
# 3        March 09, 2020          Opening statement at briefing on COVID-19
# 4        April 17, 2019                       PDP-Laban campaign, Batangas
# ..                  ...                                                ...
# 300     October 4, 2016                             Sulong Pilipinas-Luzon
# 301     October 4, 2016                    Philippine Army, Fort Bonifacio
# 302    October 02, 2016               37th Masskara Festival, Bacolod City
# 303  September 30, 2016  9th National Biennial Summit on Women in Conmm...
# 304  September 30, 2016                                 Arrival from Hanoi
#
#                                                    url  \
# 0    https://www.mindanews.com/duterte-files/2020/0...
# 1    https://www.mindanews.com/duterte-files/2020/0...
# 2    https://www.mindanews.com/mindaviews/2020/03/d...
# 3    https://www.mindanews.com/duterte-files/2020/0...
# 4    https://www.mindanews.com/duterte-files/2019/0...
# ..                                                 ...
# 300  https://www.mindanews.com/duterte-files/2016/1...
# 301  https://www.mindanews.com/duterte-files/2016/1...
# 302  https://www.mindanews.com/duterte-files/2016/1...
# 303  https://www.mindanews.com/duterte-files/2016/1...
# 304  https://www.mindanews.com/duterte-files/2016/1...
#
#                                             transcript  \
# 0    \nPRESIDENT RODRIGO ROA DUTERTE: Let us start ...
# 1    \nPRESIDENT DUTERTE: Maraming salamat Presiden...
# 2    It has been a week since we called for a Commu...
# 3    As usual I am late because my boat will not st...
# 4    Kindly sit down. Magandang gabi po sa inyong l...
# ..                                                 ...
# 300  SPEECH OF\n PRESIDENT RODRIGO ROA DUTERTE\n DU...
# 301  Presidential Communications Office\nPresidenti...
# 302  Presidential Communications Office \nPresident...
# 303  PRESIDENTIAL COMMUNICATIONS OFFICE \nPRESIDENT...
# 304  \nPRESIDENT DUTERTE: Good morning ma’am.\nPRES...
#
#                                              locations
# 0                                           Davao City
# 1                                                  NaN
# 2                                        23 March 2020
# 3            the Heroes Hall, Malacañan Palace, Manila
# 4    Batangas City Sports Center – Coliseum, Batang...
# ..                                                 ...
# 300  Mayuree Grand Ballroom, Dusit Thani Hotel, Mak...
# 301                        Fort Bonifacio, Taguig City
# 302  Bacolod City Public Plaza, Bacolod City, Negro...
# 303                         Apo View Hotel, Davao City
# 304                                         Davao City
#
# [305 rows x 5 columns]
